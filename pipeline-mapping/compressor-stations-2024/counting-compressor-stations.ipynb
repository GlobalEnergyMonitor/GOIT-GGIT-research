# %%
import geopandas

# %%
file_location = '/Users/baird/Google Drive/Shared drives/GEM Shared Drive/Programs/Oil & Gas Program/Global Oil and Gas Infrastructure Trackers (GOIT, GGIT)/Data - from external orgs and reports/Compressor stations from HIFLD/'
file_name = 'Natural_Gas_Compressor_Stations.geojson'

# %%
compressors_gdf = geopandas.read_file(file_location+file_name)

# %%
compressors_gdf.columns
# Out:
# Index(['OBJECTID', 'GCOMPID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TYPE', 'STATUS', 'COUNTY', 'COUNTYFIPS', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE', 'NAICS_CODE', 'NAICS_DESC', 'SOURCE', 'SOURCEDATE',
#        'VAL_METHOD', 'VAL_DATE', 'WEBSITE', 'PIPECO', 'COMPID', 'OPERATOR',
#        'POSREL', 'NUM_UNITS', 'CERT_HP', 'PLANT_COST', 'EXP_FUEL', 'EXP_OTHER',
#        'GAS_COMPRE', 'OP_COMP_HR', 'OP_NUM_COM', 'OP_DATE_PE', 'EXP_POWER',
#        'ELEC_COMPR', 'geometry'],
#       dtype='object')

# %%
compressors_gdf.OPERATOR.unique().__len__()
# Out:
# 150

# %%
compressors_gdf.PIPECO.unique().__len__()
# Out:
# 150

# %%
for i in sorted(compressors_gdf.PIPECO.unique()):
    print(i)
# Out:
# 979968 ALBERTA LTD.
# ALGONQUIN GAS TRANSMISSION, LLC
# ALLIANCE PIPELINE
# ALPHABOW ENERGY LTD.
# ALTAGAS UTILITIES INC.
# ANR PIPELINE COMPANY
# ANR STORAGE COMPANY
# BAYTEX ENERGY LTD.
# BELLATRIX EXPLORATION LTD.
# BORDER MIDSTREAM SERVICES, LTD.
# CAMPUS ENERGY PARTNERS OPERATION
# CANADIAN NATURAL RESOURCES
# CANADIAN NATURAL RESOURCES LIMITED
# CANADIAN OIL & GAS INTERNATIONAL INC
# CANLIN RESOURCES PARTNERSHIP
# CARDINAL ENERGY LTD.
# CAROLINA GAS TRANSMISSION CORPORATION
# CENOVUS ENERGY INC.
# CENTERPOINT ENERGY - MISSISSIPPI RIVER TRANSMISSION, LLC
# CENTERPOINT ENERGY GAS TRANSMISSION COMPANY, LLC
# CHEYENNE PLAINS GAS PIPELINE COMPANY, LLC
# CIMARRON RIVER PIPELINE, LLC
# CITATION O&G
# CITY OF MEDICINE HAT
# COLORADO INTERSTATE GAS COMPANY, L.L.C.
# COLUMBIA GAS TRANSMISSION,LLC
# COLUMBIA GULF TRANSMISSION COMPANY
# CONA RESOURCES LTD.
# CRESCENT POINT ENERGY CORP.
# CRESCENT POINT RESOURCES PARTNERSHIP
# DELPHI ENERGY CORP.
# DESTIN PIPELINE COMPANY, L.L.C.
# ...

# %%
compressors_gdf.shape
# Out:
# (1768, 38)

# %%
compressors_gdf.plot()
# Out:
# <Axes: >

# %%
compressors_gdf.loc[compressors_gdf.PIPECO=='PACIFIC GAS AND ELECTRIC'].plot()
# Out:
# <Axes: >

# %%
compressors_gdf.loc[compressors_gdf.PIPECO=='GREAT LAKES GAS TRANSMISSION LIMITED PTRSHP'].plot()
# Out:
# <Axes: >
