# %%
import pandas
pandas.options.display.max_colwidth = None #set_option('max_colwidth', None)
pandas.options.display.max_columns = 20#None#(100)#set_option('max_columns', None)

import numpy
import pygsheets
import datetime
import scipy
import sklearn.linear_model
import sklearn.cluster
import re

import matplotlib.pyplot as mp

# %% [markdown]
# # import pipelines dataset

# %%
gc = pygsheets.authorize(service_account_env_var='GDRIVE_API_CREDENTIALS')

#spreadsheet = gc.open_by_key('1foPLE6K-uqFlaYgLPAUxzeXfDO5wOOqE7tibNHeqTek')
spreadsheet = gc.open_by_key('1PKsCoVnfnCEalDBOF0Fmny0-pg1qy86DoReNHI-97WM') # version from 6 March 2023 for EGT report

gas_pipes = spreadsheet.worksheet('title', 'Gas pipelines').get_as_df(start='A2')
oil_pipes = spreadsheet.worksheet('title', 'Oil/NGL pipelines').get_as_df(start='A2')

gas_pipes = gas_pipes.drop('WKTFormat', axis=1) # delete WKTFormat column
oil_pipes = oil_pipes.drop('WKTFormat', axis=1)
pipes_df_orig = gas_pipes.copy()

# remove empty cells for pipes, owners
pipes_df_orig = pipes_df_orig.loc[pipes_df_orig.PipelineName!='']
pipes_df_orig = pipes_df_orig.loc[pipes_df_orig.Wiki!='']
pipes_df_orig = pipes_df_orig.loc[pipes_df_orig.Fuel.isin(['Gas','Hydrogen'])]

#get other relevant sheets
country_ratios_df = spreadsheet.worksheet('title', 'Country ratios by pipeline').get_as_df()

# %%
country_ratios_df.replace('--', numpy.nan, inplace=True)
pipes_df_orig.replace('--',numpy.nan,inplace=True)
pipes_df_orig['ProposalYear'] = pipes_df_orig['ProposalYear'].replace('',numpy.nan)
region_df_orig = spreadsheet.worksheet('title', 'Region dictionary').get_as_df(start='A2')

# %%
region_df_eu = region_df_orig.copy()[region_df_orig['EuropeanUnion']=='Yes']
region_df_egt = region_df_orig.copy()[region_df_orig['EuroGasTracker']=='Yes']
region_df_europe = region_df_orig.copy()[region_df_orig['Region']=='Europe']
region_df_eu_uk = region_df_orig.copy()[(region_df_orig['Region']=='Europe') | 
                                          (region_df_orig['Country'].isin(['United Kingdom','Israel']))]

# %%
region_df_touse = region_df_eu.copy()

# %%
# subset the pipelines to use
# can't use pipes_df_touse... because some of the pipelines get eliminated if they're not in the same country...
pipes_df_touse = pipes_df_orig.loc[
    ~pipes_df_orig['Countries'].apply(
        lambda x: set(x.split(', ')).isdisjoint(set(region_df_touse['Country'].tolist()))
    )]

pipes_df_touse_h2 = pipes_df_touse.loc[(pipes_df_touse.Fuel=='Hydrogen')|
                                       (pipes_df_touse.H2Status!='')]
pipes_df_touse = pipes_df_touse.loc[pipes_df_touse.Fuel=='Gas']
pipes_df_orig_gas = pipes_df_orig.loc[(pipes_df_orig.Fuel=='Gas')]
country_ratios_df_touse = country_ratios_df.loc[#(country_ratios_df.Country.isin(region_df_touse['Country'].tolist()))&
                                                (country_ratios_df.Fuel=='Gas')]

country_ratios_df_touse_eu27 = country_ratios_df.loc[(country_ratios_df.Country.isin(region_df_touse['Country'].tolist()))&
                                                (country_ratios_df.Fuel=='Gas')]

# %%
country_ratios_df_touse.shape
# Out:
# (3665, 34)

# %%
western_eu = ['Ireland', 'France', 'Belgium', 'Netherlands', 
              'Luxembourg', 'Germany', 'Austria'] 

eastern_eu = ['Estonia', 'Latvia', 'Lithuania', 'Poland', 'Czech Republic', 
              'Slovakia', 'Slovenia', 'Croatia', 'Hungary', 'Romania', 'Bulgaria'] 

southern_eu = ['Portugal', 'Spain', 'Italy', 
               'Malta', 'Greece', 'Cyprus']

northern_eu = ['Sweden', 'Finland', 'Denmark']

# %% [markdown]
# # cost estimates for EU 27 member states

# %% [markdown]
# ## outliers and special cases

# %% [raw]
# outliers_projectids = ['P3109', ]
#
# # P3109 = Valchi Dol–Preselka Pipeline replacement project, not a good new pipeline cost estimate

# %% [markdown]
# ### correct Poland-Ukraine Interconnector

# %%
# https://www.gem.wiki/Poland-Ukraine_Interconnector_Gas_Pipeline
# our country_ratios code calculates this is half in each country, but it's not
country_ratios_df_touse.loc[(country_ratios_df_touse.PipelineName=='Poland-Ukraine Interconnector Gas Pipeline')&
                      (country_ratios_df_touse.Country=='Poland'),'MergedKmByCountry'] = 1.5

country_ratios_df_touse.loc[(country_ratios_df_touse.PipelineName=='Poland-Ukraine Interconnector Gas Pipeline')&
                      (country_ratios_df_touse.Country=='Ukraine'),'MergedKmByCountry'] = 99.0

# %% [markdown]
# ### correct Gas Interconnection Poland-Lithuania (our fractional calc doesn't get it right)

# %%
country_ratios_df_touse.loc[(country_ratios_df_touse.PipelineName=='Gas Interconnection Poland-Lithuania')&
                      (country_ratios_df_touse.Country=='Poland'),'MergedKmByCountry'] = 343.0

country_ratios_df_touse.loc[(country_ratios_df_touse.PipelineName=='Gas Interconnection Poland-Lithuania')&
                      (country_ratios_df_touse.Country=='Lithuania'),'MergedKmByCountry'] = 165.0

# %% [markdown]
# ## exploring alternative cost calculations
#
# * if a given pipeline is super long and costs more than a short one per km, then should it be weighed more heavily in calculating the EU-average pipeline cost? the idea is that longer pipelines probably cost a significantly larger amount to build... look at the plot of that first perhaps
#
# pipeline cost vs length?

# %%
ax = pipes_df_orig.plot.scatter('LengthKnownKm','CostEuro')

# %% [markdown]
# ### regression estimate: given length, estimate cost

# %%
pipes_df_toregress = pipes_df_touse.loc[(~pipes_df_touse.LengthKnownKm.isnull())&
                                       (~pipes_df_touse.CostEuro.isnull())&
                                       (pipes_df_touse.LengthKnownKm>0)]

# calculate projects with same name/cost, drop the first of the same pipeline names...
same_name_and_cost = pipes_df_toregress.loc[(pipes_df_toregress.duplicated('CostEuroPerKm'))&
                       (pipes_df_toregress.duplicated('PipelineName'))].drop_duplicates('PipelineName', keep='first')
pipes_df_toregress_dropdupes = pipes_df_toregress.drop(same_name_and_cost.index)

# # look at the full global dataset
# pipes_df_toregress = pipes_df_orig.loc[(~pipes_df_orig.LengthKnownKm.isnull())&
#                                         (~pipes_df_orig.CostEuro.isnull())&
#                                         (pipes_df_orig.LengthKnownKm!=0)]#&
#                                         #(pipes_df_orig.LengthKnownKm>100)&
#                                         #(pipes_df_orig.LengthKnownKm<1000)]

# %% [markdown]
# ### gentle cluster analysis

# %%
num_clusters = 2
kmeans_cluster = sklearn.cluster.KMeans(n_clusters=num_clusters, 
                                        init='random', 
                                        n_init=10, 
                                        max_iter=300, 
                                        tol=1e-4,
                                       random_state=42)

km_fit = kmeans_cluster.fit_predict(X=pipes_df_toregress_dropdupes.LengthKnownKm.to_numpy().reshape(-1,1),
                   y=pipes_df_toregress_dropdupes.CostEuro.to_numpy().reshape(-1,1))

# %%
colors=['darkred','orange','green','blue','purple']

for i in range(num_clusters):
    mp.scatter(pipes_df_toregress_dropdupes.LengthKnownKm.to_numpy().reshape(-1,1)[km_fit == i],
               pipes_df_toregress_dropdupes.CostEuro.to_numpy().reshape(-1,1)[km_fit == i],
               edgecolor=colors[i], color='None')

#mp.xlim(0,1000)
#mp.ylim(0,0.5e10)
# mp.scatter(pipes_df_toregress.LengthKnownKm.to_numpy().reshape(-1,1)[km_fit == 2],
#            pipes_df_toregress.CostEuro.to_numpy().reshape(-1,1)[km_fit == 2],
#            color='slateblue', s=10)

# %%
ts_estimator = sklearn.linear_model.TheilSenRegressor(random_state=42, fit_intercept=False)
ts_estimator.fit(X=pipes_df_toregress_dropdupes.LengthKnownKm.to_numpy().reshape(-1,1),
                 y=pipes_df_toregress_dropdupes.CostEuro.to_numpy().reshape(-1,1))

r_estimator = sklearn.linear_model.RANSACRegressor(random_state=42,
                                                   estimator=sklearn.linear_model.LinearRegression(fit_intercept=False))
r_estimator.fit(X=pipes_df_toregress_dropdupes.LengthKnownKm.to_numpy().reshape(-1,1),
                y=pipes_df_toregress_dropdupes.CostEuro.to_numpy().reshape(-1,1))

ols_estimator = sklearn.linear_model.LinearRegression(fit_intercept=False)
ols_estimator.fit(X=pipes_df_toregress_dropdupes.LengthKnownKm.to_numpy().reshape(-1,1),
                  y=pipes_df_toregress_dropdupes.CostEuro.to_numpy().reshape(-1,1))

ts_slope, ts_intercept, ts_low_slope, ts_high_slope = scipy.stats.mstats.theilslopes(y=pipes_df_toregress_dropdupes.CostEuro.tolist(), 
                                                                                     x=pipes_df_toregress_dropdupes.LengthKnownKm.tolist(),
                                                                                     alpha=0.1, )

s_slope, s_intercept = scipy.stats.mstats.siegelslopes(y=pipes_df_toregress_dropdupes.CostEuro.tolist(), 
                                                       x=pipes_df_toregress_dropdupes.LengthKnownKm.tolist())
# Out:
# /Users/baird/mambaforge/envs/gem/lib/python3.10/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
ax = pipes_df_toregress_dropdupes.plot.scatter('LengthKnownKm','CostEuro')

xmin, xmax = ax.get_xlim()
ymin, ymax = ax.get_ylim()

#ax.set_xlim(0,200)
#ax.set_ylim(0,0.4e9)
xvals = numpy.linspace(xmin,xmax,1000)

ts_pred = ts_estimator.predict(xvals.reshape(-1,1))
r_pred = r_estimator.predict(xvals.reshape(-1,1))
ols_pred = ols_estimator.predict(xvals.reshape(-1,1))

ax.plot(xvals, ts_slope*xvals+ts_intercept, label = 'scipy Theil-Sen regression', c='red')
ax.plot(xvals, ts_low_slope*xvals+ts_intercept, label='scipy conf. interval', c='red', ls=':')
ax.plot(xvals, ts_high_slope*xvals+ts_intercept, c='red', ls=':')

ax.plot(xvals, ts_pred, label='scikit-learn Theil-Sen', c='green')
ax.plot(xvals, r_pred, label='scikit-learn RANSAC', c='lightgreen')
ax.plot(xvals, ols_pred, label='scikit-learn OLS', c='gray')

ax.legend()

print(ols_estimator.coef_/1e6, "OLS")
print(ts_estimator.coef_/1e6, "TS")
print(r_estimator.estimator_.coef_/1e6, "R")
print(ts_slope/1e6, "scipy TS slope")
print(pipes_df_toregress_dropdupes.CostEuroPerKm.mean()/1e6, "straight-up mean")
# Out:
# [[4.01993203]] OLS
# [1.21497253] TS
# [[1.13243081]] R
# 1.9555555555555555 scipy TS slope
# 2.0004776767976344 straight-up mean

# %% [markdown]
# ## cost decision!
#
# I'm going to use the full linear regression slope and the drop-duplicates average

# %% [markdown]
# ### now use these country-specific costs as multipliers on within-country kilometers
#
# LARGER MEAN

# %%
ols_estimator.coef_[0][0]/1e6
# Out:
# 4.019932032583462

# %%
mean_cost_per_km = ols_estimator.coef_[0][0]/1e6

country_ratios_df_touse['TotalEstCostEuroMillionsHigh'] = numpy.nan

for idx,row in country_ratios_df_touse.iterrows():
    country_ratios_df_touse.loc[idx,'TotalEstCostEuroMillionsHigh'] = row['MergedKmByCountry'] * mean_cost_per_km

# now replace the ones that we have exact numbers for...
costs_exist_TF = ~country_ratios_df_touse['CostEuroPerKm'].isna()
country_ratios_df_touse.loc[costs_exist_TF,'TotalEstCostEuroMillionsHigh'] = \
    country_ratios_df_touse[costs_exist_TF]['CostEuroPerKm']/1e6 * \
    country_ratios_df_touse[costs_exist_TF]['MergedKmByCountry']
# Out:
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_57358/2322650868.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_ratios_df_touse['TotalEstCostEuroMillionsHigh'] = numpy.nan

# %% [markdown]
# SMALLER MEAN

# %%
pipes_df_toregress_dropdupes.CostEuroPerKm.mean()/1e6
# Out:
# 2.0004776767976344

# %%
mean_cost_per_km = pipes_df_toregress_dropdupes.CostEuroPerKm.mean()/1e6

country_ratios_df_touse['TotalEstCostEuroMillionsLow'] = numpy.nan

for idx,row in country_ratios_df_touse.iterrows():
    country_ratios_df_touse.loc[idx,'TotalEstCostEuroMillionsLow'] = row['MergedKmByCountry'] * mean_cost_per_km

# now replace the ones that we have exact numbers for...
costs_exist_TF = ~country_ratios_df_touse['CostEuro'].isna()

country_ratios_df_touse.loc[costs_exist_TF,'TotalEstCostEuroMillionsLow'] = \
    country_ratios_df_touse[costs_exist_TF]['CostEuroPerKm']/1e6 * \
    country_ratios_df_touse[costs_exist_TF]['MergedKmByCountry']
country_ratios_df_touse.loc[costs_exist_TF,'TotalEstCostEuroMillionsHigh'] = \
    country_ratios_df_touse[costs_exist_TF]['CostEuroPerKm']/1e6 * \
    country_ratios_df_touse[costs_exist_TF]['MergedKmByCountry']

country_ratios_df_touse.loc[(country_ratios_df_touse['PipelineName']=='Trans-Adriatic Gas Pipeline')&
                            (country_ratios_df_touse['SegmentName']=='TAP Expansion')&
                            (country_ratios_df_touse['Country']=='Italy'), ['TotalEstCostEuroMillionsLow','TotalEstCostEuroMillionsHigh']] = \
country_ratios_df.loc[(country_ratios_df.ProjectID=='P3203'),'CostEuro'].values[0]/1e6 * 2/3 * 0.5

country_ratios_df_touse.loc[(country_ratios_df_touse['PipelineName']=='Trans-Adriatic Gas Pipeline')&
                            (country_ratios_df_touse['SegmentName']=='TAP Expansion')&
                            (country_ratios_df_touse['Country']=='Greece'), ['TotalEstCostEuroMillionsLow','TotalEstCostEuroMillionsHigh']] = \
country_ratios_df.loc[(country_ratios_df.ProjectID=='P3203'),'CostEuro'].values[0]/1e6 * 2/3 * 0.5
# Out:
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_57358/275472991.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_ratios_df_touse['TotalEstCostEuroMillionsLow'] = numpy.nan

# %%
country_ratios_df_touse['TotalEstCostEuroMillionsMean'] = \
    country_ratios_df_touse[['TotalEstCostEuroMillionsLow','TotalEstCostEuroMillionsHigh']].mean(axis=1)
# Out:
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_57358/1592955527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_ratios_df_touse['TotalEstCostEuroMillionsMean'] = \

# %%
output_columns = ['Country',
                  'PipelineName',
                  'SegmentName',
                  'Status',
                  'CapacityBcm/y',
                  'MergedKmByCountry',
                  'TotalEstCostEuroMillionsMean',
                  'TotalEstCostEuroMillionsLow',
                  'TotalEstCostEuroMillionsHigh']
country_ratios_df_touse_excel = country_ratios_df_touse[country_ratios_df_touse['Status'].isin(['Proposed','Construction'])]
country_ratios_df_touse_excel = country_ratios_df_touse.sort_values(['Status',
                                                                     'PipelineName',
                                                                     'TotalEstCostEuroMillionsLow',
                                                                     'TotalEstCostEuroMillionsHigh'],
                                                                    ascending=[True,True,False,False])
country_ratios_df_touse_excel.replace(numpy.nan, '')
country_ratios_df_touse_excel = country_ratios_df_touse_excel[output_columns]

# %% [markdown]
# ## print export, import, and within-EU pipelines
#
# planned pipelines to import gas into the EU

# %%
# get the pipelines that import into the EU, export out, and are completely within
pipes_df_eu_imports = pipes_df_orig.copy()[(pipes_df_orig['Fuel']=='Gas')&
              (~pipes_df_orig['StartCountry'].isin(region_df_touse.Country))&
              (pipes_df_orig['EndCountry'].isin(region_df_touse.Country))]

pipes_df_eu_exports = pipes_df_orig.copy()[(pipes_df_orig['Fuel']=='Gas')&
              (pipes_df_orig['StartCountry'].isin(region_df_touse.Country))&
              (~pipes_df_orig['EndCountry'].isin(region_df_touse.Country))]

pipes_df_eu_within = pipes_df_orig.copy()[(pipes_df_orig['Fuel']=='Gas')&
              (pipes_df_orig['StartCountry'].isin(region_df_touse.Country))&
              (pipes_df_orig['EndCountry'].isin(region_df_touse.Country))]

# %% [raw]
# pipes_df_eu_exports.loc[pipes_df_eu_exports.Status.isin(['Proposed','Construction'])].ProjectID

# %% [raw]
# pipes_df_eu_imports[pipes_df_eu_imports['Status'].isin(['Proposed','Construction'])][
#     ['ProjectID',
#      'Status',
#      'PipelineName',
#      'Wiki',
#      'CapacityBcm/y',
#      'Countries',
#      'LengthMergedKm']
# ].sort_values('Status').style.hide_index()

# %% [raw]
# pipes_df_eu_exports[pipes_df_eu_exports['Status'].isin(['Proposed','Construction'])][['ProjectID','Status','PipelineName','Wiki','CapacityBcm/y','Countries','LengthMergedKm']].sort_values('Status').style.hide_index()

# %% [raw]
# pipes_df_eu_within[pipes_df_eu_within['Status'].isin(['Proposed','Construction'])][['ProjectID','PipelineName','Wiki','CapacityBcm/y','Countries','LengthMergedKm']].style.hide_index()

# %% [markdown]
# ## Table A2

# %%
pipes_df_touse.loc[(pipes_df_touse.StartRegion!='Europe')&
                            (pipes_df_touse.EndRegion=='Europe')&
                            (pipes_df_touse.Status.isin(['Proposed','Construction']))].ProjectID
# Out:
# 249     P0463
# 263     P0479
# 358     P0732
# 421     P0827
# 1790    P3204
# 1791    P3205
# 1792    P3206
# 1818    P3281
# Name: ProjectID, dtype: object

# %%
# only construction, proposed project IDs here, built on a list:
import_projectids = [
'P0463', # Nigeria-Morocco Gas Pipeline (have in table, don't count it)
'P0479',
#'P0684', # in 2022 (Baltic Pipe Project, now operating)
'P0702',
'P0732',
'P0827', # east med (have in table but don't count it)
'P3206', # east med expansion (have in table but don't count it)
'P1321',
'P1324',
#'P1773', # this is the Siret-Khotyn Gas Pipeline, doesn't count because Romania-Ukraine Interconnector already covers it
#'P2264',
'P3203', # Trans-Adriatic Gas Pipeline TAP Expansion, also P3204
#'P3204', # 0 new km
#'P3205', # 0 new km
#'P3281', # 0 new km
'P3335', # this is a duplicate of P2264
'P1773', # Romania-Ukraine Interconnector; this is a segment: Gheraesti-Siret Gas Pipeline (Ukraine to Romania, bidirectional), added manually
#'P3522', # UK-Ireland interconnector
'P4399'
]

all_other_projectids = list(set(country_ratios_df_touse.loc[
    country_ratios_df_touse.Status.isin(['Proposed','Construction'])].ProjectID) - set(import_projectids))

output_columns = ['Country',
                  'PipelineName',
                  'Status',
                  'CapacityBcm/y',
                  'MergedKmByCountry',
                  'TotalEstCostEuroMillionsMean',]
                  #'TotalEstCostEuroMillionsLow',
                  #'TotalEstCostEuroMillionsHigh']

country_ratios_df_touse.loc[(country_ratios_df_touse.ProjectID.isin(import_projectids))&
                            (country_ratios_df_touse.Country.isin(region_df_touse.Country))].sort_values(['Status','PipelineName',
                                                                                                   'TotalEstCostEuroMillionsLow'], 
                                                                                                  ascending=[True,True,False])[output_columns].replace(numpy.nan,'').style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_51e64">
#   <thead>
#     <tr>
#       <th id="T_51e64_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_51e64_level0_col1" class="col_heading level0 col1" >PipelineName</th>
#       <th id="T_51e64_level0_col2" class="col_heading level0 col2" >Status</th>
#       <th id="T_51e64_level0_col3" class="col_heading level0 col3" >CapacityBcm/y</th>
#       <th id="T_51e64_level0_col4" class="col_heading level0 col4" >MergedKmByCountry</th>
#       <th id="T_51e64_level0_col5" class="col_heading level0 col5" >TotalEstCostEuroMillionsMean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_51e64_row0_col0" class="data row0 col0" >Croatia</td>
#       <td id="T_51e64_row0_col1" class="data row0 col1" >Bosnia and Herzegovina–Croatia South Interconnection Gas Pipeline</td>
#       <td id="T_51e64_row0_col2" class="data row0 col2" >Proposed</td>
#       <td id="T_51e64_row0_col3" class="data row0 col3" >1.500000</td>
#       <td id="T_51e64_row0_col4" class="data row0 col4" >63.440000</td>
#       <td id="T_51e64_row0_col5" class="data row0 col5" >41.373913</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row1_col0" class="data row1 col0" >Cyprus</td>
#       <td id="T_51e64_row1_col1" class="data row1 col1" >Cyprus-Turkey Gas Pipeline</td>
#       <td id="T_51e64_row1_col2" class="data row1 col2" >Proposed</td>
#       <td id="T_51e64_row1_col3" class="data row1 col3" >3.100000</td>
#       <td id="T_51e64_row1_col4" class="data row1 col4" >48.110000</td>
#       <td id="T_51e64_row1_col5" class="data row1 col5" >165.560823</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row2_col0" class="data row2 col0" >Greece</td>
#       <td id="T_51e64_row2_col1" class="data row2 col1" >East Med Gas Pipeline</td>
#       <td id="T_51e64_row2_col2" class="data row2 col2" >Proposed</td>
#       <td id="T_51e64_row2_col3" class="data row2 col3" >10.000000</td>
#       <td id="T_51e64_row2_col4" class="data row2 col4" >1274.860000</td>
#       <td id="T_51e64_row2_col5" class="data row2 col5" >4090.459893</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row3_col0" class="data row3 col0" >Cyprus</td>
#       <td id="T_51e64_row3_col1" class="data row3 col1" >East Med Gas Pipeline</td>
#       <td id="T_51e64_row3_col2" class="data row3 col2" >Proposed</td>
#       <td id="T_51e64_row3_col3" class="data row3 col3" >10.000000</td>
#       <td id="T_51e64_row3_col4" class="data row3 col4" >569.350000</td>
#       <td id="T_51e64_row3_col5" class="data row3 col5" >1826.791444</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row4_col0" class="data row4 col0" >Greece</td>
#       <td id="T_51e64_row4_col1" class="data row4 col1" >East Med Gas Pipeline</td>
#       <td id="T_51e64_row4_col2" class="data row4 col2" >Proposed</td>
#       <td id="T_51e64_row4_col3" class="data row4 col3" >10.000000</td>
#       <td id="T_51e64_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_51e64_row4_col5" class="data row4 col5" ></td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row5_col0" class="data row5 col0" >Cyprus</td>
#       <td id="T_51e64_row5_col1" class="data row5 col1" >East Med Gas Pipeline</td>
#       <td id="T_51e64_row5_col2" class="data row5 col2" >Proposed</td>
#       <td id="T_51e64_row5_col3" class="data row5 col3" >10.000000</td>
#       <td id="T_51e64_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_51e64_row5_col5" class="data row5 col5" ></td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row6_col0" class="data row6 col0" >Croatia</td>
#       <td id="T_51e64_row6_col1" class="data row6 col1" >Ionian Adriatic Gas Pipeline</td>
#       <td id="T_51e64_row6_col2" class="data row6 col2" >Proposed</td>
#       <td id="T_51e64_row6_col3" class="data row6 col3" >5.000000</td>
#       <td id="T_51e64_row6_col4" class="data row6 col4" >262.010000</td>
#       <td id="T_51e64_row6_col5" class="data row6 col5" >284.329372</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row7_col0" class="data row7 col0" >Cyprus</td>
#       <td id="T_51e64_row7_col1" class="data row7 col1" >Israel Cyprus Gas Pipeline</td>
#       <td id="T_51e64_row7_col2" class="data row7 col2" >Proposed</td>
#       <td id="T_51e64_row7_col3" class="data row7 col3" >4.000000</td>
#       <td id="T_51e64_row7_col4" class="data row7 col4" >152.290000</td>
#       <td id="T_51e64_row7_col5" class="data row7 col5" >227.443994</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row8_col0" class="data row8 col0" >Spain</td>
#       <td id="T_51e64_row8_col1" class="data row8 col1" >Nigeria-Morocco Gas Pipeline</td>
#       <td id="T_51e64_row8_col2" class="data row8 col2" >Proposed</td>
#       <td id="T_51e64_row8_col3" class="data row8 col3" >30.000000</td>
#       <td id="T_51e64_row8_col4" class="data row8 col4" >137.850000</td>
#       <td id="T_51e64_row8_col5" class="data row8 col5" >558.603754</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row9_col0" class="data row9 col0" >Bulgaria</td>
#       <td id="T_51e64_row9_col1" class="data row9 col1" >North Macedonia–Bulgaria Gas Pipeline</td>
#       <td id="T_51e64_row9_col2" class="data row9 col2" >Proposed</td>
#       <td id="T_51e64_row9_col3" class="data row9 col3" >2.060000</td>
#       <td id="T_51e64_row9_col4" class="data row9 col4" >5.190000</td>
#       <td id="T_51e64_row9_col5" class="data row9 col5" >1.085182</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row10_col0" class="data row10 col0" >Romania</td>
#       <td id="T_51e64_row10_col1" class="data row10 col1" >Romania-Ukraine Interconnector</td>
#       <td id="T_51e64_row10_col2" class="data row10 col2" >Proposed</td>
#       <td id="T_51e64_row10_col3" class="data row10 col3" >2.810000</td>
#       <td id="T_51e64_row10_col4" class="data row10 col4" >0.060000</td>
#       <td id="T_51e64_row10_col5" class="data row10 col5" >0.080000</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row11_col0" class="data row11 col0" >Greece</td>
#       <td id="T_51e64_row11_col1" class="data row11 col1" >Trans-Adriatic Gas Pipeline</td>
#       <td id="T_51e64_row11_col2" class="data row11 col2" >Proposed</td>
#       <td id="T_51e64_row11_col3" class="data row11 col3" >10.000000</td>
#       <td id="T_51e64_row11_col4" class="data row11 col4" >0.000000</td>
#       <td id="T_51e64_row11_col5" class="data row11 col5" >345.000000</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row12_col0" class="data row12 col0" >Italy</td>
#       <td id="T_51e64_row12_col1" class="data row12 col1" >Trans-Adriatic Gas Pipeline</td>
#       <td id="T_51e64_row12_col2" class="data row12 col2" >Proposed</td>
#       <td id="T_51e64_row12_col3" class="data row12 col3" >10.000000</td>
#       <td id="T_51e64_row12_col4" class="data row12 col4" >0.000000</td>
#       <td id="T_51e64_row12_col5" class="data row12 col5" >345.000000</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row13_col0" class="data row13 col0" >Bulgaria</td>
#       <td id="T_51e64_row13_col1" class="data row13 col1" >White Stream Gas Pipeline</td>
#       <td id="T_51e64_row13_col2" class="data row13 col2" >Proposed</td>
#       <td id="T_51e64_row13_col3" class="data row13 col3" >32.000000</td>
#       <td id="T_51e64_row13_col4" class="data row13 col4" >156.470000</td>
#       <td id="T_51e64_row13_col5" class="data row13 col5" >471.006754</td>
#     </tr>
#     <tr>
#       <td id="T_51e64_row14_col0" class="data row14 col0" >Romania</td>
#       <td id="T_51e64_row14_col1" class="data row14 col1" >White Stream Gas Pipeline</td>
#       <td id="T_51e64_row14_col2" class="data row14 col2" >Proposed</td>
#       <td id="T_51e64_row14_col3" class="data row14 col3" >32.000000</td>
#       <td id="T_51e64_row14_col4" class="data row14 col4" >121.400000</td>
#       <td id="T_51e64_row14_col5" class="data row14 col5" >365.438869</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Table A3 (appendix)

# %% [markdown]
# ### longer than 150 km

# %%
# must be longer than 150 total, and the segment must be located within the EU
projectids_threshold = list(
    set(country_ratios_df_touse.loc[(country_ratios_df_touse.MergedKmByPipeline>150)&
                                   (country_ratios_df_touse.ProjectID.isin(all_other_projectids))&
                                   (country_ratios_df_touse.Country.isin(region_df_touse.Country))]['ProjectID'])
)

projectids_under_threshold = list(
    set(all_other_projectids) - set(projectids_threshold)
)

projectids_threshold.__len__()
# Out:
# 22

# %%
output_columns = ['Country',
                  'PipelineName',
                  #'Status',
                  'CapacityBcm/y',
                  'MergedKmByPipeline',
                  'MergedKmByCountry',
                  'TotalEstCostEuroMillionsMean']#,
                  #'TotalEstCostEuroMillionsLow',
                  #'TotalEstCostEuroMillionsHigh']

country_ratios_df_touse.replace(numpy.nan,'').loc[
    (country_ratios_df_touse.ProjectID.isin(projectids_threshold))&
    (country_ratios_df_touse.Country.isin(region_df_touse.Country.tolist()))].sort_values([
    'Status','PipelineName','TotalEstCostEuroMillionsLow'], ascending=[True,True,False])[output_columns].style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_43f29">
#   <thead>
#     <tr>
#       <th id="T_43f29_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_43f29_level0_col1" class="col_heading level0 col1" >PipelineName</th>
#       <th id="T_43f29_level0_col2" class="col_heading level0 col2" >CapacityBcm/y</th>
#       <th id="T_43f29_level0_col3" class="col_heading level0 col3" >MergedKmByPipeline</th>
#       <th id="T_43f29_level0_col4" class="col_heading level0 col4" >MergedKmByCountry</th>
#       <th id="T_43f29_level0_col5" class="col_heading level0 col5" >TotalEstCostEuroMillionsMean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_43f29_row0_col0" class="data row0 col0" >Bulgaria</td>
#       <td id="T_43f29_row0_col1" class="data row0 col1" >Bulgaria-Serbia Interconnector Gas Pipeline</td>
#       <td id="T_43f29_row0_col2" class="data row0 col2" >1.800000</td>
#       <td id="T_43f29_row0_col3" class="data row0 col3" >170.000000</td>
#       <td id="T_43f29_row0_col4" class="data row0 col4" >63.710000</td>
#       <td id="T_43f29_row0_col5" class="data row0 col5" >50.218470</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row1_col0" class="data row1 col0" >Poland</td>
#       <td id="T_43f29_row1_col1" class="data row1 col1" >Gustorzyn-Wronów Gas Pipeline</td>
#       <td id="T_43f29_row1_col2" class="data row1 col2" ></td>
#       <td id="T_43f29_row1_col3" class="data row1 col3" >308.000000</td>
#       <td id="T_43f29_row1_col4" class="data row1 col4" >308.000000</td>
#       <td id="T_43f29_row1_col5" class="data row1 col5" >927.143095</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row2_col0" class="data row2 col0" >Italy</td>
#       <td id="T_43f29_row2_col1" class="data row2 col1" >Methanization of Sardinia Project</td>
#       <td id="T_43f29_row2_col2" class="data row2 col2" ></td>
#       <td id="T_43f29_row2_col3" class="data row2 col3" >573.000000</td>
#       <td id="T_43f29_row2_col4" class="data row2 col4" >573.000000</td>
#       <td id="T_43f29_row2_col5" class="data row2 col5" >642.853210</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row3_col0" class="data row3 col0" >Poland</td>
#       <td id="T_43f29_row3_col1" class="data row3 col1" >Pogórska-Wola-Tworzen Gas Pipeline</td>
#       <td id="T_43f29_row3_col2" class="data row3 col2" ></td>
#       <td id="T_43f29_row3_col3" class="data row3 col3" >168.000000</td>
#       <td id="T_43f29_row3_col4" class="data row3 col4" >168.000000</td>
#       <td id="T_43f29_row3_col5" class="data row3 col5" >300.500001</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row4_col0" class="data row4 col0" >Italy</td>
#       <td id="T_43f29_row4_col1" class="data row4 col1" >Adriatica Pipeline</td>
#       <td id="T_43f29_row4_col2" class="data row4 col2" >8.800000</td>
#       <td id="T_43f29_row4_col3" class="data row4 col3" >170.000000</td>
#       <td id="T_43f29_row4_col4" class="data row4 col4" >170.000000</td>
#       <td id="T_43f29_row4_col5" class="data row4 col5" >553.600000</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row5_col0" class="data row5 col0" >Germany</td>
#       <td id="T_43f29_row5_col1" class="data row5 col1" >Bielefeld-Magdeburg Gas Pipeline</td>
#       <td id="T_43f29_row5_col2" class="data row5 col2" ></td>
#       <td id="T_43f29_row5_col3" class="data row5 col3" >159.000000</td>
#       <td id="T_43f29_row5_col4" class="data row5 col4" >159.000000</td>
#       <td id="T_43f29_row5_col5" class="data row5 col5" >478.622572</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row6_col0" class="data row6 col0" >Romania</td>
#       <td id="T_43f29_row6_col1" class="data row6 col1" >Black Sea Shore–Podișor Gas Pipeline</td>
#       <td id="T_43f29_row6_col2" class="data row6 col2" ></td>
#       <td id="T_43f29_row6_col3" class="data row6 col3" >308.000000</td>
#       <td id="T_43f29_row6_col4" class="data row6 col4" >308.000000</td>
#       <td id="T_43f29_row6_col5" class="data row6 col5" >360.000000</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row7_col0" class="data row7 col0" >Portugal</td>
#       <td id="T_43f29_row7_col1" class="data row7 col1" >Celorico-Spanish Border Gas Pipeline</td>
#       <td id="T_43f29_row7_col2" class="data row7 col2" ></td>
#       <td id="T_43f29_row7_col3" class="data row7 col3" >162.000000</td>
#       <td id="T_43f29_row7_col4" class="data row7 col4" >162.000000</td>
#       <td id="T_43f29_row7_col5" class="data row7 col5" >114.999999</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row8_col0" class="data row8 col0" >Cyprus</td>
#       <td id="T_43f29_row8_col1" class="data row8 col1" >Cyprus-Egypt Gas Pipeline</td>
#       <td id="T_43f29_row8_col2" class="data row8 col2" >8.000000</td>
#       <td id="T_43f29_row8_col3" class="data row8 col3" >310.000000</td>
#       <td id="T_43f29_row8_col4" class="data row8 col4" >32.950000</td>
#       <td id="T_43f29_row8_col5" class="data row8 col5" >97.514057</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row9_col0" class="data row9 col0" >Czech Republic</td>
#       <td id="T_43f29_row9_col1" class="data row9 col1" >Czech-Polish Interconnector Gas Pipeline (CPI)</td>
#       <td id="T_43f29_row9_col2" class="data row9 col2" ></td>
#       <td id="T_43f29_row9_col3" class="data row9 col3" >207.000000</td>
#       <td id="T_43f29_row9_col4" class="data row9 col4" >155.340000</td>
#       <td id="T_43f29_row9_col5" class="data row9 col5" >210.670176</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row10_col0" class="data row10 col0" >Poland</td>
#       <td id="T_43f29_row10_col1" class="data row10 col1" >Czech-Polish Interconnector Gas Pipeline (CPI)</td>
#       <td id="T_43f29_row10_col2" class="data row10 col2" ></td>
#       <td id="T_43f29_row10_col3" class="data row10 col3" >207.000000</td>
#       <td id="T_43f29_row10_col4" class="data row10 col4" >51.660000</td>
#       <td id="T_43f29_row10_col5" class="data row10 col5" >70.060649</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row11_col0" class="data row11 col0" >Bulgaria</td>
#       <td id="T_43f29_row11_col1" class="data row11 col1" >Dubnitza-Nikolaevo Gas Pipeline</td>
#       <td id="T_43f29_row11_col2" class="data row11 col2" ></td>
#       <td id="T_43f29_row11_col3" class="data row11 col3" >321.370000</td>
#       <td id="T_43f29_row11_col4" class="data row11 col4" >321.370000</td>
#       <td id="T_43f29_row11_col5" class="data row11 col5" >967.389534</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row12_col0" class="data row12 col0" >Romania</td>
#       <td id="T_43f29_row12_col1" class="data row12 col1" >Eastring Pipeline</td>
#       <td id="T_43f29_row12_col2" class="data row12 col2" >20.000000</td>
#       <td id="T_43f29_row12_col3" class="data row12 col3" >1208.000000</td>
#       <td id="T_43f29_row12_col4" class="data row12 col4" >650.960000</td>
#       <td id="T_43f29_row12_col5" class="data row12 col5" >1401.072847</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row13_col0" class="data row13 col0" >Hungary</td>
#       <td id="T_43f29_row13_col1" class="data row13 col1" >Eastring Pipeline</td>
#       <td id="T_43f29_row13_col2" class="data row13 col2" >20.000000</td>
#       <td id="T_43f29_row13_col3" class="data row13 col3" >1208.000000</td>
#       <td id="T_43f29_row13_col4" class="data row13 col4" >293.660000</td>
#       <td id="T_43f29_row13_col5" class="data row13 col5" >632.049669</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row14_col0" class="data row14 col0" >Bulgaria</td>
#       <td id="T_43f29_row14_col1" class="data row14 col1" >Eastring Pipeline</td>
#       <td id="T_43f29_row14_col2" class="data row14 col2" >20.000000</td>
#       <td id="T_43f29_row14_col3" class="data row14 col3" >1208.000000</td>
#       <td id="T_43f29_row14_col4" class="data row14 col4" >233.100000</td>
#       <td id="T_43f29_row14_col5" class="data row14 col5" >501.705298</td>
#     </tr>
#     <tr>
#       <td id="T_43f29_row15_col0" class="data row15 col0" >Slovakia</td>
#       <td id="T_43f29_row15_col1" class="data row15 col1" >Eastring Pipeline</td>
#       <td id="T_43f29_row15_col2" class="data row15 col2" >20.000000</td>
#       <td id="T_43f29_row15_col3" cla

# %% [markdown]
# ### shorter than 150 km

# %%
below_threshold_df = country_ratios_df_touse.loc[(country_ratios_df_touse.ProjectID.isin(projectids_under_threshold))&
                                                 (country_ratios_df_touse.Country.isin(region_df_touse.Country))]#.groupby('Status')

below_threshold_df.groupby('Status')[['MergedKmByCountry',
                                      'TotalEstCostEuroMillionsMean',
                                      'TotalEstCostEuroMillionsLow',
                                      'TotalEstCostEuroMillionsHigh']].sum()
# Out:
#               MergedKmByCountry  TotalEstCostEuroMillionsMean
# Status
# Construction             345.70                    317.051417  \
# Proposed                3083.69                   6504.668808
#
#               TotalEstCostEuroMillionsLow  TotalEstCostEuroMillionsHigh
# Status
# Construction                   315.839744                    318.263089
# Proposed                      5241.025537                   7768.312080

# %% [markdown]
# # import terminals now

# %%
credentials_directory = '/Users/baird/Dropbox/_google-api/'
gc = pygsheets.authorize(service_account_env_var='GDRIVE_API_CREDENTIALS')
#spreadsheet = gc.open_by_key('1tcS6Wd-Wp-LTDpLzFgJY_RSNDnbyubW3J_9HKIAys4A')
#spreadsheet = gc.open_by_key('1BHiidrJnzh96Em3KrqBpCoWaJ3GB5OeCY9dHVaEDEFs') # mar 22 2022 version for EGT
spreadsheet = gc.open_by_key('1d0kLE0WmAn9b4XdugffiEaAHGWy6EhyF7zY1DM12zCc') # 1 Mar 2023 version for EGT report

#spreadsheet[1] "Gas Pipelines" tab is the second index
terms_df_orig = spreadsheet.worksheet('title', 'Terminals').get_as_df(start='A2')

# %%
# replace all -- with nans
terms_df_orig.replace('--', numpy.nan, inplace=True)
# only keep LNG terminals (remove oil)
terms_df_orig = terms_df_orig.loc[terms_df_orig.Fuel=='LNG']
# remove anything without a wiki page
terms_df_orig = terms_df_orig.loc[terms_df_orig.Wiki!='']
# remove N/A statuses
terms_df_orig = terms_df_orig.loc[terms_df_orig.Status!='']

# %%
terms_df_touse = terms_df_orig.loc[(terms_df_orig['Country'].isin(region_df_touse['Country']))&
                                   (terms_df_orig.Fuel=='LNG')]
terms_df_touse_imports = terms_df_touse.loc[(terms_df_orig['Country'].isin(region_df_touse['Country']))&
                                            (terms_df_touse['Import/Export']=='Import')]

# %%
terms_df_touse_imports.loc[terms_df_touse_imports.Status.isin(['Proposed','Construction'])].shape
# Out:
# (45, 81)

# %% [markdown]
# #### pull out what to regress for costs

# %%
terms_df_floating_toregress = terms_df_touse.loc[(terms_df_touse['Import/Export']=='Import')&
                                                 (terms_df_touse.Floating=='yes')&
                                                 (~terms_df_touse['CostEuroPerBcm/y'].isnull())]
terms_df_floating_toregress_dropdupes = terms_df_floating_toregress.drop_duplicates('CostEuroPerBcm/y')

# %%
terms_df_onshore_toregress = terms_df_touse.loc[(terms_df_touse['Import/Export']=='Import')&
                                                (terms_df_touse.Floating=='')&
                                                (~terms_df_touse['CostEuroPerBcm/y'].isnull())&
                                                (~terms_df_touse.UnitName.str.contains('expansion', flags=re.IGNORECASE, regex=True))]
terms_df_onshore_toregress_dropdupes = terms_df_onshore_toregress.drop_duplicates('CostEuroPerBcm/y')

# %% [markdown]
# ### regressions for costs

# %% [markdown]
# #### floating terminals

# %%
ts_estimator_f = sklearn.linear_model.TheilSenRegressor(random_state=42, fit_intercept=False)
ts_estimator_f.fit(X=terms_df_floating_toregress['CapacityInBcm/y'].to_numpy().reshape(-1,1),
                 y=terms_df_floating_toregress.CostEuro.to_numpy().reshape(-1,1))

r_estimator_f = sklearn.linear_model.RANSACRegressor(random_state=42,
                                                   estimator=sklearn.linear_model.LinearRegression(fit_intercept=False))
r_estimator_f.fit(X=terms_df_floating_toregress['CapacityInBcm/y'].to_numpy().reshape(-1,1),
                y=terms_df_floating_toregress.CostEuro.to_numpy().reshape(-1,1))

ols_estimator_f = sklearn.linear_model.LinearRegression(fit_intercept=False)
ols_estimator_f.fit(X=terms_df_floating_toregress['CapacityInBcm/y'].to_numpy().reshape(-1,1),
                  y=terms_df_floating_toregress.CostEuro.to_numpy().reshape(-1,1))

ts_slope_f, ts_intercept_f, ts_low_slope_f, ts_high_slope_f = scipy.stats.mstats.theilslopes(y=terms_df_floating_toregress.CostEuro.tolist(), 
                                                                            x=terms_df_floating_toregress['CapacityInBcm/y'].tolist(),
                                                                            alpha=0.1, )

s_slope_f, s_intercept_f = scipy.stats.mstats.siegelslopes(y=terms_df_floating_toregress.CostEuro.tolist(), 
                                                       x=terms_df_floating_toregress['CapacityInBcm/y'].tolist())
# Out:
# /Users/baird/mambaforge/envs/gem/lib/python3.10/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
ax = terms_df_floating_toregress_dropdupes.plot.scatter('CapacityInBcm/y', 'CostEuro')

xmin, xmax = ax.get_xlim()
ymin, ymax = ax.get_ylim()

#ax.set_xlim(0,200)
#ax.set_ylim(0,0.4e9)
xvals = numpy.linspace(xmin,xmax,1000)

ts_pred_f = ts_estimator_f.predict(xvals.reshape(-1,1))
r_pred_f = r_estimator_f.predict(xvals.reshape(-1,1))
ols_pred_f = ols_estimator_f.predict(xvals.reshape(-1,1))

ax.plot(xvals, ts_slope_f*xvals+ts_intercept_f, label = 'scipy Theil-Sen regression', c='red')
ax.plot(xvals, ts_low_slope_f*xvals+ts_intercept_f, label='scipy conf. interval', c='red', ls=':')
ax.plot(xvals, ts_high_slope_f*xvals+ts_intercept_f, c='red', ls=':')

ax.plot(xvals, ts_pred_f, label='scikit-learn Theil-Sen', c='green')
ax.plot(xvals, r_pred_f, label='scikit-learn RANSAC', c='lightgreen')
ax.plot(xvals, ols_pred_f, label='scikit-learn OLS', c='gray')

#ax.plot(

#ax.plot(xvals, s_slope*xvals+s_intercept, label = 'scipy.stats', c='orange')

ax.legend()

print(ols_estimator_f.coef_/1e6, "OLS")
print(ts_estimator_f.coef_/1e6, "TS")
print(r_estimator_f.estimator_.coef_/1e6, "R")
print(ts_slope_f/1e6, "scipy TS slope")
print(terms_df_floating_toregress_dropdupes['CostEuroPerBcm/y'].mean()/1e6, "straight-up mean")
# Out:
# [[70.22029989]] OLS
# [61.25] TS
# [[62.35774681]] R
# 66.66666666666667 scipy TS slope
# 87.40097522988886 straight-up mean

# %% [raw]
# terms_df_floating_toregress_dropdupes[['TerminalName','UnitName','CostEuro','CapacityInBcm/y']].sort_values('CapacityInBcm/y')

# %% [markdown]
# #### onshore terminals

# %%
ts_estimator_o = sklearn.linear_model.TheilSenRegressor(random_state=42, fit_intercept=False)
ts_estimator_o.fit(X=terms_df_onshore_toregress['CapacityInBcm/y'].to_numpy().reshape(-1,1),
                 y=terms_df_onshore_toregress.CostEuro.to_numpy().reshape(-1,1))

r_estimator_o = sklearn.linear_model.RANSACRegressor(random_state=42,
                                                   estimator=sklearn.linear_model.LinearRegression(fit_intercept=False))
r_estimator_o.fit(X=terms_df_onshore_toregress['CapacityInBcm/y'].to_numpy().reshape(-1,1),
                y=terms_df_onshore_toregress.CostEuro.to_numpy().reshape(-1,1))

ols_estimator_o = sklearn.linear_model.LinearRegression(fit_intercept=False)
ols_estimator_o.fit(X=terms_df_onshore_toregress['CapacityInBcm/y'].to_numpy().reshape(-1,1),
                  y=terms_df_onshore_toregress.CostEuro.to_numpy().reshape(-1,1))

ts_slope_o, ts_intercept_o, ts_low_slope_o, ts_high_slope_o = scipy.stats.mstats.theilslopes(y=terms_df_onshore_toregress.CostEuro.tolist(), 
                                                                            x=terms_df_onshore_toregress['CapacityInBcm/y'].tolist(),
                                                                            alpha=0.1, )

s_slope_o, s_intercept_o = scipy.stats.mstats.siegelslopes(y=terms_df_onshore_toregress.CostEuro.tolist(), 
                                                       x=terms_df_onshore_toregress['CapacityInBcm/y'].tolist())
# Out:
# /Users/baird/mambaforge/envs/gem/lib/python3.10/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
ax = terms_df_onshore_toregress_dropdupes.plot.scatter('CapacityInBcm/y', 'CostEuro')

xmin, xmax = ax.get_xlim()
ymin, ymax = ax.get_ylim()

#ax.set_xlim(0,200)
#ax.set_ylim(0,0.4e9)
xvals = numpy.linspace(xmin,xmax,1000)

ts_pred_o = ts_estimator_o.predict(xvals.reshape(-1,1))
r_pred_o = r_estimator_o.predict(xvals.reshape(-1,1))
ols_pred_o = ols_estimator_o.predict(xvals.reshape(-1,1))

ax.plot(xvals, ts_slope_o*xvals+ts_intercept_o, label = 'scipy Theil-Sen regression', c='red')
ax.plot(xvals, ts_low_slope_o*xvals+ts_intercept_o, label='scipy conf. interval', c='red', ls=':')
ax.plot(xvals, ts_high_slope_o*xvals+ts_intercept_o, c='red', ls=':')

ax.plot(xvals, ts_pred_o, label='scikit-learn Theil-Sen', c='green')
ax.plot(xvals, r_pred_o, label='scikit-learn RANSAC', c='lightgreen')
ax.plot(xvals, ols_pred_o, label='scikit-learn OLS', c='gray')

#ax.plot(

#ax.plot(xvals, s_slope*xvals+s_intercept, label = 'scipy.stats', c='orange')

ax.legend()

print(ols_estimator_o.coef_/1e6, "OLS")
print(ts_estimator_o.coef_/1e6, "TS")
print(r_estimator_o.estimator_.coef_/1e6, "R")
print(ts_slope_o/1e6, "scipy TS slope")
# Out:
# [[83.06265718]] OLS
# [125.] TS
# [[81.41650426]] R
# 76.97100671181944 scipy TS slope

# %%
terms_df_floating_toregress_dropdupes['CostEuroPerBcm/y'].mean()/1e6
# Out:
# 87.40097522988886

# %%
terms_df_onshore_toregress_dropdupes['CostEuroPerBcm/y'].mean()/1e6
# Out:
# 200.19259648538463

# %% [markdown]
# ## calculate floating costs (high and low estimates)

# %% [markdown]
# SMALLER MEAN

# %%
print(ols_estimator_f.coef_[0][0]/1e6)
print(ols_estimator_o.coef_[0][0]/1e6)
# Out:
# 70.22029989097626
# 83.06265717569723

# %%
mean_cost_per_bcmy_floating = ols_estimator_f.coef_[0][0]/1e6
mean_cost_per_bcmy_onshore = ols_estimator_o.coef_[0][0]/1e6

terms_df_eu27_import_future = terms_df_touse.loc[(terms_df_touse.Status.isin(['Proposed','Construction']))&
                                                 (terms_df_touse['Import/Export']=='Import')]

# do for floating
terms_df_eu27_import_future['TotalEstCostEuroMillionsLow'] = numpy.nan

terms_df_eu27_import_future.loc[(terms_df_eu27_import_future['Floating']=='yes'),
                                'TotalEstCostEuroMillionsLow'] = \
terms_df_eu27_import_future.loc[(terms_df_eu27_import_future['Floating']=='yes'),
                                'CapacityInBcm/y'] * mean_cost_per_bcmy_floating

# now do for onshore
#terms_df_eu27_import_future.loc[:,'TotalEstCostEuroMillionsLow'] = numpy.nan
terms_df_eu27_import_future.loc[(terms_df_eu27_import_future['Floating']==''),
                                'TotalEstCostEuroMillionsLow'] = \
terms_df_eu27_import_future.loc[(terms_df_eu27_import_future['Floating']==''),
                                'CapacityInBcm/y'] * mean_cost_per_bcmy_onshore

# then replace any that we have already
# now replace the ones that we have exact numbers for...
costs_exist_TF = ~terms_df_eu27_import_future['CostEuro'].isna()
terms_df_eu27_import_future.loc[costs_exist_TF,'TotalEstCostEuroMillionsLow'] = \
    terms_df_eu27_import_future[costs_exist_TF]['CostEuro']/1e6 #*euro_multiplier/1e6
# Out:
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_57358/1020654288.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   terms_df_eu27_import_future['TotalEstCostEuroMillionsLow'] = numpy.nan

# %% [markdown]
# LARGER MEAN

# %%
mean_cost_per_bcmy_floating = terms_df_floating_toregress_dropdupes['CostEuroPerBcm/y'].mean()/1e6
mean_cost_per_bcmy_onshore = terms_df_onshore_toregress_dropdupes['CostEuroPerBcm/y'].mean()/1e6

# terms_df_eu27_import_future = terms_df_touse.loc[(terms_df_touse.Status.isin(['Proposed','Construction']))&
#                                                  (terms_df_touse['Import/Export']=='Import')]

# do for floating
terms_df_eu27_import_future['TotalEstCostEuroMillionsHigh'] = numpy.nan

terms_df_eu27_import_future.loc[(terms_df_eu27_import_future['Floating']=='yes'),
                                'TotalEstCostEuroMillionsHigh'] = \
terms_df_eu27_import_future.loc[(terms_df_eu27_import_future['Floating']=='yes'),
                                'CapacityInBcm/y'] * mean_cost_per_bcmy_floating

# now do for onshore
#terms_df_eu27_import_future.loc[:,'TotalEstCostEuroMillionsLow'] = numpy.nan
terms_df_eu27_import_future.loc[(terms_df_eu27_import_future['Floating']==''),
                                'TotalEstCostEuroMillionsHigh'] = \
terms_df_eu27_import_future.loc[(terms_df_eu27_import_future['Floating']==''),
                                'CapacityInBcm/y'] * mean_cost_per_bcmy_onshore

# then replace any that we have already
# now replace the ones that we have exact numbers for...
costs_exist_TF = ~terms_df_eu27_import_future['CostEuro'].isna()
terms_df_eu27_import_future.loc[costs_exist_TF,'TotalEstCostEuroMillionsHigh'] = \
    terms_df_eu27_import_future[costs_exist_TF]['CostEuro']/1e6 #*euro_multiplier/1e6
# Out:
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_57358/1859383821.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   terms_df_eu27_import_future['TotalEstCostEuroMillionsHigh'] = numpy.nan

# %%
terms_df_eu27_import_future['TotalEstCostEuroMillionsMean'] = \
    terms_df_eu27_import_future[['TotalEstCostEuroMillionsLow', 'TotalEstCostEuroMillionsHigh']].mean(axis=1)
# Out:
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_57358/4095347764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   terms_df_eu27_import_future['TotalEstCostEuroMillionsMean'] = \

# %% [markdown]
# ### correct outliers/special cases

# %%
# Zeebrugge terminal is 116 million for BOTH expansion projects, so set one equal to zero so it's not counted twice
#T042601	https://www.gem.wiki/Fluxys_Zeebrugge_LNG_Terminal	Zeebrugge LNG Terminal, 2024 Expansion
#T042602	https://www.gem.wiki/Fluxys_Zeebrugge_LNG_Terminal	Zeebrugge LNG Terminal, 2026 Expansion
outliers_comboids = ['T042602']
terms_df_eu27_import_future.loc[
    terms_df_eu27_import_future.ComboID.isin(outliers_comboids),
    ['TotalEstCostEuroMillionsMean','TotalEstCostEuroMillionsLow','TotalEstCostEuroMillionsHigh']] = 0.0

# %% [markdown]
# # Table A1

# %%
terms_df_eu27_import_future['CapacityInBcm/y'].sum()
# Out:
# 227.2

# %%
output_columns = ['Country',
                  #'TerminalName',
                  'TerminalNameUnitName',
                  #'UnitName',
                  'CapacityInBcm/y',
                  #'Status',
                  #'Import/Export',
                  'TotalEstCostEuroMillionsMean']#,
                  #'TotalEstCostEuroMillionsLow',
                  #'TotalEstCostEuroMillionsHigh']

terms_df_eu27_import_future['TerminalNameUnitName'] = (terms_df_eu27_import_future.TerminalName + ' ' + terms_df_eu27_import_future.UnitName).str.strip()
terms_df_eu27_import_future.sort_values(['Status','TerminalNameUnitName'],
                                        ascending=[True,True])[output_columns].replace(numpy.nan,'').style.hide(axis='index')
# Out:
# /var/folders/fl/t07mc8053p33mn6mdmvp45580000gn/T/ipykernel_57358/1966433922.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   terms_df_eu27_import_future['TerminalNameUnitName'] = (terms_df_eu27_import_future.TerminalName + ' ' + terms_df_eu27_import_future.UnitName).str.strip()
# <style type="text/css">
# </style>
# <table id="T_cb3d6">
#   <thead>
#     <tr>
#       <th id="T_cb3d6_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_cb3d6_level0_col1" class="col_heading level0 col1" >TerminalNameUnitName</th>
#       <th id="T_cb3d6_level0_col2" class="col_heading level0 col2" >CapacityInBcm/y</th>
#       <th id="T_cb3d6_level0_col3" class="col_heading level0 col3" >TotalEstCostEuroMillionsMean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cb3d6_row0_col0" class="data row0 col0" >Greece</td>
#       <td id="T_cb3d6_row0_col1" class="data row0 col1" >Alexandroupolis FSRU</td>
#       <td id="T_cb3d6_row0_col2" class="data row0 col2" >5.500000</td>
#       <td id="T_cb3d6_row0_col3" class="data row0 col3" >360.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row1_col0" class="data row1 col0" >Cyprus</td>
#       <td id="T_cb3d6_row1_col1" class="data row1 col1" >Cyprus LNG Terminal</td>
#       <td id="T_cb3d6_row1_col2" class="data row1 col2" >0.820000</td>
#       <td id="T_cb3d6_row1_col3" class="data row1 col3" >337.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row2_col0" class="data row2 col0" >Estonia</td>
#       <td id="T_cb3d6_row2_col1" class="data row2 col1" >Paldiski FSRU</td>
#       <td id="T_cb3d6_row2_col2" class="data row2 col2" ></td>
#       <td id="T_cb3d6_row2_col3" class="data row2 col3" >500.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row3_col0" class="data row3 col0" >Germany</td>
#       <td id="T_cb3d6_row3_col1" class="data row3 col1" >Stade FSRU</td>
#       <td id="T_cb3d6_row3_col2" class="data row3 col2" >5.000000</td>
#       <td id="T_cb3d6_row3_col3" class="data row3 col3" >394.053188</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row4_col0" class="data row4 col0" >Belgium</td>
#       <td id="T_cb3d6_row4_col1" class="data row4 col1" >Zeebrugge LNG Terminal 2024 Expansion</td>
#       <td id="T_cb3d6_row4_col2" class="data row4 col2" >6.390000</td>
#       <td id="T_cb3d6_row4_col3" class="data row4 col3" >116.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row5_col0" class="data row5 col0" >Belgium</td>
#       <td id="T_cb3d6_row5_col1" class="data row5 col1" >Zeebrugge LNG Terminal 2026 Expansion</td>
#       <td id="T_cb3d6_row5_col2" class="data row5 col2" >1.770000</td>
#       <td id="T_cb3d6_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row6_col0" class="data row6 col0" >Poland</td>
#       <td id="T_cb3d6_row6_col1" class="data row6 col1" >Świnoujście Polskie LNG Terminal Expansion 2</td>
#       <td id="T_cb3d6_row6_col2" class="data row6 col2" >2.100000</td>
#       <td id="T_cb3d6_row6_col3" class="data row6 col3" >297.418016</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row7_col0" class="data row7 col0" >Greece</td>
#       <td id="T_cb3d6_row7_col1" class="data row7 col1" >Argo FSRU</td>
#       <td id="T_cb3d6_row7_col2" class="data row7 col2" >5.200000</td>
#       <td id="T_cb3d6_row7_col3" class="data row7 col3" >226.500000</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row8_col0" class="data row8 col0" >Romania</td>
#       <td id="T_cb3d6_row8_col1" class="data row8 col1" >Black Sea LNG Terminal Import Facility</td>
#       <td id="T_cb3d6_row8_col2" class="data row8 col2" ></td>
#       <td id="T_cb3d6_row8_col3" class="data row8 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row9_col0" class="data row9 col0" >Germany</td>
#       <td id="T_cb3d6_row9_col1" class="data row9 col1" >Brunsbüttel LNG Terminal</td>
#       <td id="T_cb3d6_row9_col2" class="data row9 col2" >8.000000</td>
#       <td id="T_cb3d6_row9_col3" class="data row9 col3" >1000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row10_col0" class="data row10 col0" >Greece</td>
#       <td id="T_cb3d6_row10_col1" class="data row10 col1" >Dioriga FSRU</td>
#       <td id="T_cb3d6_row10_col2" class="data row10 col2" >2.600000</td>
#       <td id="T_cb3d6_row10_col3" class="data row10 col3" >300.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row11_col0" class="data row11 col0" >France</td>
#       <td id="T_cb3d6_row11_col1" class="data row11 col1" >Dunkirk LNG Terminal Debottlenecking</td>
#       <td id="T_cb3d6_row11_col2" class="data row11 col2" >2.720000</td>
#       <td id="T_cb3d6_row11_col3" class="data row11 col3" >385.227145</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row12_col0" class="data row12 col0" >Spain</td>
#       <td id="T_cb3d6_row12_col1" class="data row12 col1" >El Musel LNG Terminal</td>
#       <td id="T_cb3d6_row12_col2" class="data row12 col2" >8.000000</td>
#       <td id="T_cb3d6_row12_col3" class="data row12 col3" >1133.021015</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row13_col0" class="data row13 col0" >France</td>
#       <td id="T_cb3d6_row13_col1" class="data row13 col1" >Fos Cavaou LNG Terminal Expansion 1 (Debottlenecking)</td>
#       <td id="T_cb3d6_row13_col2" class="data row13 col2" >2.750000</td>
#       <td id="T_cb3d6_row13_col3" class="data row13 col3" >389.475974</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row14_col0" class="data row14 col0" >France</td>
#       <td id="T_cb3d6_row14_col1" class="data row14 col1" >Fos Cavaou LNG Terminal Expansion 2</td>
#       <td id="T_cb3d6_row14_col2" class="data row14 col2" >5.500000</td>
#       <td id="T_cb3d6_row14_col3" class="data row14 col3" >778.951948</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row15_col0" class="data row15 col0" >Netherlands</td>
#       <td id="T_cb3d6_row15_col1" class="data row15 col1" >Gate LNG Terminal Phase 3 Expansion</td>
#       <td id="T_cb3d6_row15_col2" class="data row15 col2" >1.500000</td>
#       <td id="T_cb3d6_row15_col3" class="data row15 col3" >212.441440</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row16_col0" class="data row16 col0" >Netherlands</td>
#       <td id="T_cb3d6_row16_col1" class="data row16 col1" >Gate LNG Terminal Phase 4 Expansion</td>
#       <td id="T_cb3d6_row16_col2" class="data row16 col2" >2.500000</td>
#       <td id="T_cb3d6_row16_col3" class="data row16 col3" >354.069067</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row17_col0" class="data row17 col0" >Italy</td>
#       <td id="T_cb3d6_row17_col1" class="data row17 col1" >Gioia Tauro LNG Terminal</td>
#       <td id="T_cb3d6_row17_col2" class="data row17 col2" >12.000000</td>
#       <td id="T_cb3d6_row17_col3" class="data row17 col3" >1000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row18_col0" class="data row18 col0" >Croatia</td>
#       <td id="T_cb3d6_row18_col1" class="data row18 col1" >Krk FSRU Phase 1</td>
#       <td id="T_cb3d6_row18_col2" class="data row18 col2" >3.200000</td>
#       <td id="T_cb3d6_row18_col3" class="data row18 col3" >25.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row19_col0" class="data row19 col0" >Croatia</td>
#       <td id="T_cb3d6_row19_col1" class="data row19 col1" >Krk FSRU Phase 2</td>
#       <td id="T_cb3d6_row19_col2" class="data row19 col2" >7.000000</td>
#       <td id="T_cb3d6_row19_col3" class="data row19 col3" >551.674463</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row20_col0" class="data row20 col0" >France</td>
#       <td id="T_cb3d6_row20_col1" class="data row20 col1" >Le Havre FSRU</td>
#       <td id="T_cb3d6_row20_col2" class="data row20 col2" >5.000000</td>
#       <td id="T_cb3d6_row20_col3" class="data row20 col3" >394.053188</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row21_col0" class="data row21 col0" >Germany</td>
#       <td id="T_cb3d6_row21_col1" class="data row21 col1" >Lubmin FSRU Phase 2 (Vessel 1)</td>
#       <td id="T_cb3d6_row21_col2" class="data row21 col2" >2.000000</td>
#       <td id="T_cb3d6_row21_col3" class="data row21 col3" >14.814815</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row22_col0" class="data row22 col0" >Germany</td>
#       <td id="T_cb3d6_row22_col1" class="data row22 col1" >Lubmin FSRU Phase 2 (Vessel 2)</td>
#       <td id="T_cb3d6_row22_col2" class="data row22 col2" >7.000000</td>
#       <td id="T_cb3d6_row22_col3" class="data row22 col3" >51.851852</td>
#     </tr>
#     <tr>
#       <td id="T_cb3d6_row23_col0"

# %% [markdown]
# # creating table 3 - future gas infra in EU countries

# %%
terms_df_eu27_import_future.groupby('Country')[['TotalEstCostEuroMillionsMean']].sum()
# Out:
#             TotalEstCostEuroMillionsMean
# Country
# Belgium                            116.0
# Croatia                       576.674463
# Cyprus                             337.0
# Estonia                           1150.0
# France                       2447.708254
# Germany                      6790.674505
# Greece                       2311.583415
# Ireland                       854.907658
# Italy                        4375.933977
# Latvia                             110.0
# Netherlands                   960.563695
# Poland                        917.418016
# Romania                                0
# Spain                        1133.021015

# %%
terms_df_orig.loc[(terms_df_orig.EuroCrisisTracker=='yes')&
                  (terms_df_orig.Status!='Cancelled')]['CapacityInBcm/y'].sum()
# Out:
# 188.97

# %%
terms_df_eu27_import_future.loc[terms_df_eu27_import_future.EuroCrisisTracker=='yes']['CapacityInBcm/y'].sum()
# Out:
# 147.48

# %%
# table 1 shows country totals of pipeline length, cost, LNG capacity, cost, total cost
table2_columns = ['PipelineLengthKm','PipelineCostMillionEuro',
                  'LNGImportCapacityBcm/y','LNGTerminalCostMillionEuro','TotalCostMillionEuro']
table2_df = pandas.DataFrame(columns=table2_columns, index=region_df_touse.Country.tolist())

table2_df['PipelineLengthKm'] = country_ratios_df_touse.loc[country_ratios_df_touse.ProjectID.isin(
    import_projectids+all_other_projectids)].groupby('Country')['MergedKmByCountry'].sum()

table2_df['PipelineCostMillionEuro'] = country_ratios_df_touse.loc[country_ratios_df_touse.ProjectID.isin(
    import_projectids+all_other_projectids)].groupby('Country')['TotalEstCostEuroMillionsMean'].sum()

# add half of Trans-Adriatic expansion to Italy, half to Greece
#table2_df.loc['Greece','PipelineCostMillionEuro']+=1035/2
#table2_df.loc['Italy','PipelineCostMillionEuro']+=1035/2

table2_df['LNGImportCapacityBcm/y'] = terms_df_eu27_import_future.groupby('Country')['CapacityInBcm/y'].sum()
table2_df['LNGTerminalCostMillionEuro'] = terms_df_eu27_import_future.groupby('Country')['TotalEstCostEuroMillionsMean'].sum()
table2_df['TotalCostMillionEuro'] = table2_df.loc[:,('PipelineCostMillionEuro','LNGTerminalCostMillionEuro')].sum(axis=1)

if 'Total' in table2_df.index:
    table2_df.drop(index='Total', inplace=True)   
    total = table2_df.sum(axis=0)
    total.name='Total'
    table2_df.loc['Total'] = total

else:
    total = table2_df.sum(axis=0)
    total.name='Total'
    table2_df.loc['Total'] = total

# replace NaN with ''
table2_df.replace(numpy.nan, '', inplace=True)
table2_df.replace(0.0, '', inplace=True)

# %%
table2_df#['LNGImportCapacityBcm/y'][:-1].replace('',numpy.nan).sum()
# Out:
#                PipelineLengthKm PipelineCostMillionEuro
# Austria                   59.39              178.776066  \
# Belgium
# Bulgaria                1124.62             2577.931241
# Croatia                  870.54             1016.529627
# Cyprus                   921.15             2684.692924
# Czech Republic           157.95               218.52681
# Denmark
# Estonia                     1.2                3.612246
# Finland
# France
# Germany                  582.45             1757.875419
# Greece                  2606.87             8262.417258
# Hungary                  367.62              711.430821
# Ireland                    26.0               78.265326
# Italy                   2070.45             5325.371131
# Latvia                     31.5                    26.0
# Lithuania
# Luxembourg
# Malta                     70.29              181.162528
# Netherlands               44.55              134.104626
# Poland                  1281.16             2618.122307
# Portugal                  162.0              114.999999
# Romania                 1824.17             2700.791303
# Slovakia                  29.68               63.880795
# Slovenia                  528.0             1013.350501
# Spain                    522.85             1717.532623
# Sweden
# Total                  13282.44            31385.373551
#
#                LNGImportCapacityBcm/y LNGTerminalCostMillionEuro
# Austria                                                           \
# Belgium                          8.16                      116.0
# Bulgaria
# Croatia                          10.2                 576.674463
# Cyprus                           0.82                      337.0
# Czech Republic
# Denmark
# Estonia                          6.17                     1150.0
# Finland
# France                          18.47                2447.708254
# Germany                          74.3                6790.674505
# Greece                           26.6                2311.583415
# Hungary
# Ireland                         10.85                 854.907658
# Italy                           36.25                4375.933977
# Latvia                           4.08                      110.0
# Lithuania
# Luxembourg
# Malta
# Netherlands                       9.0                 960.563695
# Poland                           14.3                 917.418016
# Portugal
# Romania
# Slovakia
# Slovenia
# Spain                             8.0                1133.021015
# Sweden
# Total                           227.2               22081.484997
#
#                TotalCostMillionEuro
# Austria                  178.776066
# Belgium                       116.0
# Bulgaria                2577.931241
# Croatia                 1593.204089
# Cyprus                  3021.692924
# Czech Republic            218.52681
# Denmark
# Estonia                 1153.612246
# Finland
# France                  2447.708254
# Germany                 8548.549923
# Greece                 10574.000674
# Hungary                  711.430821
# Ireland                  933.172984
# Italy                   9701.305107
# Latvia                        136.0
# Lithuania
# Luxembourg
# Malta                    181.162528
# Netherlands             1094.668321
# Poland                  3535.540323
# Portugal                 114.999999
# Romania                 2700.791303
# Slovakia                  63.880795
# Slovenia                1013.350501
# Spain                   2850.553638
# Sweden
# Total                  53466.858548

# %% [markdown]
# # creating table 4 from report (nsew_eu)

# %%
import_projectids
# Out:
# ['P0463',
#  'P0479',
#  'P0702',
#  'P0732',
#  'P0827',
#  'P3206',
#  'P1321',
#  'P1324',
#  'P3203',
#  'P3335',
#  'P1773',
#  'P4399']

# %%
pipes_df_orig_gas.loc[pipes_df_orig_gas.ProjectID.isin(import_projectids)][['PipelineName','Wiki']]
# Out:
#                                                            PipelineName
# 249                                        Nigeria-Morocco Gas Pipeline  \
# 263                                          Israel Cyprus Gas Pipeline
# 328                                        Ionian Adriatic Gas Pipeline
# 358                                           White Stream Gas Pipeline
# 421                                               East Med Gas Pipeline
# 787   Bosnia and Herzegovina–Croatia South Interconnection Gas Pipeline
# 788                                          Cyprus-Turkey Gas Pipeline
# 985                                      Romania-Ukraine Interconnector
# 1789                                        Trans-Adriatic Gas Pipeline
# 1792                                              East Med Gas Pipeline
# 1838                              North Macedonia–Bulgaria Gas Pipeline
#
#                                                                                                 Wiki
# 249                                                https://www.gem.wiki/Nigeria-Morocco_Gas_Pipeline
# 263                                                  https://www.gem.wiki/Israel_Cyprus_Gas_Pipeline
# 328                                                https://www.gem.wiki/Ionian_Adriatic_Gas_Pipeline
# 358                                                   https://www.gem.wiki/White_Stream_Gas_Pipeline
# 421                                                       https://www.gem.wiki/East_Med_Gas_Pipeline
# 787   https://www.gem.wiki/Bosnia_and_Herzegovina%E2%80%93Croatia_South_Interconnection_Gas_Pipeline
# 788                                                  https://www.gem.wiki/Cyprus-Turkey_Gas_Pipeline
# 985                                                   https://www.gem.wiki/Siret-Khotyn_Gas_Pipeline
# 1789                                                https://www.gem.wiki/Trans-Adriatic_Gas_Pipeline
# 1792                                                      https://www.gem.wiki/East_Med_Gas_Pipeline
# 1838                              https://www.gem.wiki/North_Macedonia%E2%80%93Bulgaria_Gas_Pipeline

# %%
region_list = [western_eu,eastern_eu,southern_eu,northern_eu]
index_list = ['Western EU','Eastern EU','Southern EU','Northern EU']
project_list = []

table4_nsew = pandas.DataFrame(0, columns=['EstCostMillionEuroConstruction',
                                           'CostNumPipesConstruction',
                                           'CostNumTermsConstruction',
                                           'PipeLengthConstruction',
                                           
                                        'CapacityInBcm/yConstruction',
                                           'CapacNumPipesConstruction',
                                           'CapacNumTermsConstruction',
                                           'CapacPipesConstruction',
                                           'CapacTermsConstruction',
                                           'PipesProjectIDsConstruction',
                                           'TermsComboIDsConstruction',
                                           
                                        'EstCostMillionEuroProposed',
                                           'CostNumPipesProposed',
                                           'CostNumTermsProposed',
                                           'PipeLengthProposed',
                                           
                                        'CapacityInBcm/yProposed',
                                           'CapacNumPipesProposed',
                                           'CapacNumTermsProposed',
                                           'CapacPipesProposed',
                                           'CapacTermsProposed'
                                           'PipesProjectIDsProposed',
                                           'TermsComboIDsProposed',
                                           
                                          ], index=range(4))

terms_w_eu = pandas.DataFrame()
terms_n_eu = pandas.DataFrame()
terms_s_eu = pandas.DataFrame()
terms_e_eu = pandas.DataFrame()

pipes_w_eu = pandas.DataFrame()
pipes_n_eu = pandas.DataFrame()
pipes_s_eu = pandas.DataFrame()
pipes_e_eu = pandas.DataFrame()

for idx,row in table4_nsew.iterrows():
    
    for STATUS in ['Proposed','Construction']:
        
        # for proposed
        # for pipeline costs, we don't care about imports only, we also care about general pipelines
        pipeline_cost = country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin([STATUS])) &
                               (country_ratios_df_touse.Country.isin(region_list[idx]))]['TotalEstCostEuroMillionsMean'].sum()
        
        pipe_cost_num = country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin([STATUS])) &
                               (country_ratios_df_touse.Country.isin(region_list[idx]))].ProjectID.unique().size
        
        pipe_length = country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin([STATUS])) &
                               (country_ratios_df_touse.Country.isin(region_list[idx]))]['MergedKmByCountry'].sum()

        pipeline_capacity = pipes_df_orig_gas.loc[(pipes_df_orig_gas.ProjectID.isin(import_projectids)) &
                                (pipes_df_orig_gas.EndCountry.isin(region_list[idx])) &
                                (pipes_df_orig_gas.Status.isin([STATUS]))]['CapacityBcm/y'].sum()
        
        pipe_cap_num = pipes_df_orig_gas.loc[(pipes_df_orig_gas.ProjectID.isin(import_projectids)) &
                                (pipes_df_orig_gas.EndCountry.isin(region_list[idx])) &
                                (pipes_df_orig_gas.Status.isin([STATUS]))]['CapacityBcm/y'].count()
        
        pipe_projectids = pipes_df_orig_gas.loc[(pipes_df_orig_gas.ProjectID.isin(import_projectids)) &
                                (pipes_df_orig_gas.EndCountry.isin(region_list[idx])) &
                                (pipes_df_orig_gas.Status.isin([STATUS]))].PipelineName.tolist()
        
        # ****************************************

        terminal_cost = terms_df_eu27_import_future.loc[(terms_df_eu27_import_future.Status.isin([STATUS])) &
                                    (terms_df_eu27_import_future.Country.isin(region_list[idx]))]['TotalEstCostEuroMillionsMean'].sum()
        term_num = terms_df_eu27_import_future.loc[(terms_df_eu27_import_future.Status.isin([STATUS])) &
                                    (terms_df_eu27_import_future.Country.isin(region_list[idx]))]['TerminalName'].count()

        terminal_capacity = terms_df_eu27_import_future.loc[(terms_df_eu27_import_future.Status.isin([STATUS])) &
                                    (terms_df_eu27_import_future.Country.isin(region_list[idx]))]['CapacityInBcm/y'].sum()
        term_comboids = terms_df_eu27_import_future.loc[(terms_df_eu27_import_future.Status.isin([STATUS])) &
                                    (terms_df_eu27_import_future.Country.isin(region_list[idx]))].TerminalName.tolist()

        # pipelines are import only
        which_pipelines_df = country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin([STATUS])) &
                               (country_ratios_df_touse.Country.isin(region_list[idx]) &
                               (country_ratios_df_touse.ProjectID.isin(import_projectids)))]
        which_terminals_df = terms_df_eu27_import_future.loc[(terms_df_eu27_import_future.Status.isin([STATUS])) &
                                    (terms_df_eu27_import_future.Country.isin(region_list[idx]))]
        
        #print(which_terminals_df.ComboID)

        if index_list[idx]=='Western EU':
            terms_w_eu = pandas.concat([terms_w_eu,which_terminals_df])
            pipes_w_eu = pandas.concat([pipes_w_eu,which_pipelines_df])
        if index_list[idx]=='Northern EU':
            terms_n_eu = pandas.concat([terms_n_eu,which_terminals_df])
            pipes_n_eu = pandas.concat([pipes_n_eu,which_pipelines_df])
        if index_list[idx]=='Eastern EU':
            terms_e_eu = pandas.concat([terms_e_eu,which_terminals_df])
            pipes_e_eu = pandas.concat([pipes_e_eu,which_pipelines_df])
        if index_list[idx]=='Southern EU':
            terms_s_eu = pandas.concat([terms_s_eu,which_terminals_df])
            pipes_s_eu = pandas.concat([pipes_s_eu,which_pipelines_df])

        table4_nsew.loc[idx, 'EstCostMillionEuro'+STATUS] += terminal_cost+pipeline_cost
        table4_nsew.loc[idx, 'CapacityInBcm/y'+STATUS] += terminal_capacity+pipeline_capacity
        table4_nsew.loc[idx, 'CapacTerms'+STATUS] = terminal_capacity
        table4_nsew.loc[idx, 'CapacPipes'+STATUS] = pipeline_capacity
        table4_nsew.loc[idx, 'CostNumTerms'+STATUS] = term_num
        table4_nsew.loc[idx, 'CapacNumTerms'+STATUS] = term_num
        table4_nsew.loc[idx, 'CostNumPipes'+STATUS] = pipe_cost_num
        table4_nsew.loc[idx, 'CapacNumPipes'+STATUS] = pipe_cap_num
        table4_nsew.loc[idx, 'PipeLength'+STATUS] = pipe_length
        table4_nsew.loc[idx, 'PipesProjectIDs'+STATUS] = '\n'.join(pipe_projectids)
        table4_nsew.loc[idx, 'TermsComboIDs'+STATUS] = '\n'.join(term_comboids)

table4_nsew.index = index_list

# add trans-adriatic
#table4_nsew.loc['Southern EU','EstCostMillionEuroProposed'] += 1035.

# %%
pandas.options.display.max_columns=None

# %%
table4_nsew
# Out:
#              EstCostMillionEuroConstruction  CostNumPipesConstruction
# Western EU                       510.053188                         0  \
# Eastern EU                      2132.330998                        12
# Southern EU                     1599.853210                         4
# Northern EU                        0.000000                         0
#
#              CostNumTermsConstruction  PipeLengthConstruction
# Western EU                          3                    0.00  \
# Eastern EU                          2                  709.91
# Southern EU                         2                  748.50
# Northern EU                         0                    0.00
#
#              CapacityInBcm/yConstruction  CapacNumPipesConstruction
# Western EU                         13.16                          0  \
# Eastern EU                          2.10                          0
# Southern EU                         6.32                          0
# Northern EU                         0.00                          0
#
#              CapacNumTermsConstruction  CapacPipesConstruction
# Western EU                           3                       0  \
# Eastern EU                           2                       0
# Southern EU                          2                       0
# Northern EU                          0                       0
#
#              CapacTermsConstruction PipesProjectIDsConstruction
# Western EU                    13.16                              \
# Eastern EU                     2.10
# Southern EU                    6.32
# Northern EU                    0.00
#
#                                               TermsComboIDsConstruction
# Western EU   Zeebrugge LNG Terminal\nZeebrugge LNG Terminal\nStade FSRU  \
# Eastern EU              Paldiski FSRU\nŚwinoujście Polskie LNG Terminal
# Southern EU                   Cyprus LNG Terminal\nAlexandroupolis FSRU
# Northern EU
#
#              EstCostMillionEuroProposed  CostNumPipesProposed
# Western EU                 12808.822361                    11  \
# Eastern EU                 11571.937131                    46
# Southern EU                24843.861660                    31
# Northern EU                    0.000000                     0
#
#              CostNumTermsProposed  PipeLengthProposed
# Western EU                     18              712.39  \
# Eastern EU                      8             5506.53
# Southern EU                    12             5605.11
# Northern EU                     0                0.00
#
#              CapacityInBcm/yProposed  CapacNumPipesProposed
# Western EU                    107.62                      0  \
# Eastern EU                     76.02                      5
# Southern EU                   132.45                      6
# Northern EU                     0.00                      0
#
#              CapacNumTermsProposed  CapacPipesProposed
# Western EU                      18                0.00  \
# Eastern EU                       8               43.37
# Southern EU                     12               67.10
# Northern EU                      0                0.00
#
#              CapacTermsProposedPipesProjectIDsProposed
# Western EU                                           0  \
# Eastern EU                                           0
# Southern EU                                          0
# Northern EU                                          0
#
#                                                                                                                                                                                                                                                                                                                                                                    TermsComboIDsProposed
# Western EU   Dunkirk LNG Terminal\nLe Havre FSRU\nMontoir LNG Terminal\nFos Cavaou LNG Terminal\nFos Cavaou LNG Terminal\nBrunsbüttel LNG Terminal\nStade LNG Terminal\nLubmin FSRU\nLubmin FSRU\nLubmin RWE FSRU\nTES Wilhelmshaven LNG Terminal\nWilhelmshaven NWO FSRU\nWilhelmshaven TES FSRU Terminal\nShannon FSRU\nPredator FSRU\nGate LNG Terminal\nGate LNG Terminal\nVTTI FSRU  \
# Eastern EU                                                                                                                                                                                                                         Krk FSRU\nKrk FSRU\nPaldiski LNG Terminal\nTallinn LNG Terminal\nRiga FSRU\nSkulte LNG Terminal\nPolish Baltic Sea Coast FSRU\nBlack Sea LNG Terminal
# Southern EU                                                                                                                                               Argo FSRU\nDioriga FSRU\nThessaloniki FSRU\nThrace FSRU\nGioia Tauro LNG Terminal\nPorto Torres FSRU Terminal\nPorto Empedocle LNG Terminal\nToscana FSRU\nPiombino FSRU\nPortovesme FSRU\nRavenna FSRU\nEl Musel LNG Terminal
# Northern EU
#
#              CapacTermsProposed
# Western EU               107.62  \
# Eastern EU                32.65
# Southern EU               65.35
# Northern EU                0.00
#
#                                                                                                                                                                                        PipesProjectIDsProposed
# Western EU
# Eastern EU   Ionian Adriatic Gas Pipeline\nWhite Stream Gas Pipeline\nBosnia and Herzegovina–Croatia South Interconnection Gas Pipeline\nRomania-Ukraine Interconnector\nNorth Macedonia–Bulgaria Gas Pipeline
# Southern EU                                    Nigeria-Morocco Gas Pipeline\nIsrael Cyprus Gas Pipeline\nEast Med Gas Pipeline\nCyprus-Turkey Gas Pipeline\nTrans-Adriatic Gas Pipeline\nEast Med Gas Pipeline
# Northern EU

# %% [markdown]
# # creating figure 1 data
#
# sum of Table 1 columns...

# %%
figure1_table_columns = ['TotalConstructionCostMillionEuro','TotalProposedCostMillionEuro','Total']
figure1_table_df = pandas.DataFrame(0, columns=figure1_table_columns, index=region_df_touse.Country,)


# for proposed
figure1_table_df['TotalProposedCostMillionEuro'] = \
country_ratios_df_touse.loc[country_ratios_df_touse.Status.isin(
    ['Proposed'])].groupby(['Country'])['TotalEstCostEuroMillionsMean'].sum()

figure1_table_df['TotalProposedCostMillionEuro'] = \
figure1_table_df['TotalProposedCostMillionEuro'].add( \
terms_df_eu27_import_future.loc[terms_df_eu27_import_future.Status.isin(
    ['Proposed'])].groupby(['Country'])['TotalEstCostEuroMillionsMean'].sum(), \
                                                    fill_value=0)

#figure1_table_df.loc['Italy','TotalProposedCostMillionEuro'] += 1035/2.
#figure1_table_df.loc['Greece','TotalProposedCostMillionEuro'] += 1035/2.

# for construction
figure1_table_df['TotalConstructionCostMillionEuro'] = \
country_ratios_df_touse.loc[country_ratios_df_touse.Status.isin(
    ['Construction'])].groupby(['Country'])['TotalEstCostEuroMillionsMean'].sum()

figure1_table_df['TotalConstructionCostMillionEuro'] = \
figure1_table_df['TotalConstructionCostMillionEuro'].add( \
terms_df_eu27_import_future.loc[terms_df_eu27_import_future.Status.isin(
    ['Construction'])].groupby(['Country'])['TotalEstCostEuroMillionsMean'].sum(), \
                                                         fill_value=0, axis=0)

figure1_table_df['Total'] = \
figure1_table_df[['TotalConstructionCostMillionEuro','TotalProposedCostMillionEuro']].sum(axis=1)
figure1_table_df.sort_values(['Total','Country'], ascending=[False, True], inplace=True)

figure1_table_df.replace(numpy.nan, '', inplace=True)
figure1_table_df.replace(0, '', inplace=True)

# %%
figure1_table_df
# Out:
#                TotalConstructionCostMillionEuro TotalProposedCostMillionEuro  \
# Country
# Greece                                    440.0                 10134.000673
# Italy                                 822.85321                  8878.451897
# Germany                              394.053188                  8154.496736
# Poland                              1552.061112                  1983.479211
# Cyprus                                    337.0                  2684.692924
# Spain                                                            2850.553638
# Romania                                                          2700.791303
# Bulgaria                               76.65764                  2501.273601
# France                                                           2447.708254
# Croatia                                                          1593.204089
# Estonia                              503.612246                        650.0
# Netherlands                                                      1094.668321
# Slovenia                                                         1013.350501
# Ireland                                                           933.172984
# Hungary                                                           711.430821
# Czech Republic                                                     218.52681
# Malta                                                             181.162528
# Austria                                                           178.776066
# Latvia                                                                 136.0
# Belgium                                   116.0
# Portugal                                                          114.999999
# Slovakia                                                           63.880795
# Denmark
# Finland
# Lithuania
# Luxembourg
# Sweden
#
#                        Total
# Country
# Greece          10574.000674
# Italy            9701.305107
# Germany          8548.549923
# Poland           3535.540323
# Cyprus           3021.692924
# Spain            2850.553638
# Romania          2700.791303
# Bulgaria         2577.931241
# France           2447.708254
# Croatia          1593.204089
# Estonia          1153.612246
# Netherlands      1094.668321
# Slovenia         1013.350501
# Ireland           933.172984
# Hungary           711.430821
# Czech Republic     218.52681
# Malta             181.162528
# Austria           178.776066
# Latvia                 136.0
# Belgium                116.0
# Portugal          114.999999
# Slovakia           63.880795
# Denmark
# Finland
# Lithuania
# Luxembourg
# Sweden

# %% [markdown]
# # report numbers

# %%
# key points
# num of gas pipelines under const in EU
country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin(['Construction']))&
                           (country_ratios_df_touse.Country.isin(region_df_touse.Country))]['MergedKmByCountry'].sum()
# Out:
# 1458.41

# %%
# total cost
country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin(['Construction']))&
                           (country_ratios_df_touse.Country.isin(region_df_touse.Country))]['TotalEstCostEuroMillionsLow'].sum()
# Out:
# 1925.5585489067287

# %%
country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin(['Construction']))&
                           (country_ratios_df_touse.Country.isin(region_df_touse.Country))]['TotalEstCostEuroMillionsHigh'].sum()
# Out:
# 2549.973835715706

# %%
# number of distinct projects
unique_const = country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin(['Construction']))&
                                          (country_ratios_df_touse.Country.isin(region_df_touse.Country))].ProjectID.unique().tolist()
print(pipes_df_orig.loc[pipes_df_orig.ProjectID.isin(unique_const)]['LengthMergedKm'].mean())
print(pipes_df_orig.loc[pipes_df_orig.ProjectID.isin(unique_const)]['LengthMergedKm'].size)
# Out:
# 97.79375
# 16

# %%
country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin(['Proposed']))&
                           (country_ratios_df_touse.Country.isin(region_df_touse.Country))]['MergedKmByCountry'].sum()
# Out:
# 11824.029999999999

# %%
country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin(['Proposed']))&
                           (country_ratios_df_touse.Country.isin(region_df_touse.Country))]['TotalEstCostEuroMillionsLow'].sum()
# Out:
# 25857.754656690784

# %%
country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin(['Proposed']))&
                           (country_ratios_df_touse.Country.isin(region_df_touse.Country))]['TotalEstCostEuroMillionsHigh'].sum()
# Out:
# 32437.46006053793

# %%
# number of distinct projects
unique_prop = country_ratios_df_touse.loc[(country_ratios_df_touse.Status.isin(['Proposed']))&
                                         (country_ratios_df_touse.Country.isin(region_df_touse.Country))].ProjectID.unique().tolist()
print(pipes_df_orig.loc[pipes_df_orig.ProjectID.isin(unique_prop)]['LengthMergedKm'].mean())
print(pipes_df_orig.loc[pipes_df_orig.ProjectID.isin(unique_prop)]['LengthMergedKm'].size)
# Out:
# 244.75926829268292
# 83

# %% [markdown]
# # how many announced since war started?

# %% [raw]
# pipes_df_orig.loc[(pipes_df_orig.Fuel=='Gas')&
#                   (pipes_df_orig.ProposalYear>=2022)&
#                   ((pipes_df_orig.StartRegion=='Europe')|
#                   (pipes_df_orig.EndRegion=='Europe'))]#.to_excel('recent_pipelines.xlsx')

# %% [markdown]
# # commissioned in 2022/2023

# %%
pipes_df_touse.loc[(pipes_df_touse.Status=='Operating')&
                   (pipes_df_touse.StartYearEarliest==2022)][['PipelineName',
                                                              'Wiki',
                                                              'Countries',
                                                              'CapacityBcm/y',
                                                              'CostEuro',
                                                              'LengthKnownKm']]#.sort_values('PipelineName').set_index('PipelineName')
# Out:
#                                        PipelineName  \
# 310                             Baltic Pipe Project
# 321            Gas Interconnection Poland-Lithuania
# 322        Gas Interconnector Greece–Bulgaria (IGB)
# 792                    Poland-Slovakia Gas Pipeline
# 1112                            Medgaz Gas Pipeline
# 1135  Beglej-Dermantsi-Batultsi-Kalugerovo Pipeline
# 1203                            Baltic Pipe Project
# 1204                            Baltic Pipe Project
# 1447                             Midia Gas Pipeline
#
#                                                                     Wiki  \
# 310                             https://www.gem.wiki/Baltic_Pipe_Project
# 321     https://www.gem.wiki/Gas_Interconnection_Poland-Lithuania_(GIPL)
# 322      https://www.gem.wiki/Gas_Interconnector_Greece_-_Bulgaria_(IGB)
# 792                    https://www.gem.wiki/Poland-Slovakia_Gas_Pipeline
# 1112                            https://www.gem.wiki/Medgaz_Gas_Pipeline
# 1135  https://www.gem.wiki/Beglej-Dermantsi-Batultsi-Kalugerovo_Pipeline
# 1203                            https://www.gem.wiki/Baltic_Pipe_Project
# 1204                            https://www.gem.wiki/Baltic_Pipe_Project
# 1447                             https://www.gem.wiki/Midia_Gas_Pipeline
#
#                             Countries  CapacityBcm/y      CostEuro  \
# 310   Norway, Denmark, Sweden, Poland           10.0  2.100000e+09
# 321                 Poland, Lithuania            2.4  5.660000e+08
# 322                  Greece, Bulgaria            3.0  2.400000e+08
# 792                  Poland, Slovakia            5.7  2.700000e+08
# 1112                   Algeria, Spain            2.7           NaN
# 1135                         Bulgaria            NaN           NaN
# 1203                           Poland            NaN           NaN
# 1204                           Poland            NaN           NaN
# 1447                          Romania            1.0           NaN
#
#       LengthKnownKm
# 310           612.5
# 321           508.0
# 322           184.0
# 792           165.0
# 1112            0.0
# 1135           58.0
# 1203          122.0
# 1204           69.0
# 1447          126.0

# %%
terms_df_touse_imports.loc[(terms_df_touse_imports.Status=='Operating')&
                           (terms_df_touse_imports.StartYearEarliest.isin([2022,2023]))][['ComboID',
                                                                              'TerminalName',
                                                                              'UnitName',
                                                                              'Wiki',
                                                                              'Country',
                                                                              'CapacityInBcm/y',
                                                                              'CostEuro',
                                                                              'StartYear1','StartMonth1']].set_index('TerminalName').replace(numpy.nan,'')
# Out:
#                                   ComboID                 UnitName  \
# TerminalName
# Krk FSRU                          T043001  2022 Capacity Expansion
# Hamina LNG Terminal               T043800
# Inkoo FSRU                        T106400
# Brunsbüttel FSRU                  T046000
# Wilhelmshaven FSRU                T045800
# Lubmin FSRU                       T107700                  Phase 1
# Revithoussa LNG Terminal          T046201   FSU Capacity Expansion
# Eemshaven FSRU                    T099700
# Świnoujście Polskie LNG Terminal  T049801                Expansion
#
#                                                                                              Wiki  \
# TerminalName
# Krk FSRU                                                            https://www.gem.wiki/Krk_FSRU
# Hamina LNG Terminal                                      https://www.gem.wiki/Hamina_LNG_Terminal
# Inkoo FSRU                                                        https://www.gem.wiki/Inkoo_FSRU
# Brunsbüttel FSRU                                            https://www.gem.wiki/Brunsbüttel_FSRU
# Wilhelmshaven FSRU                                        https://www.gem.wiki/Wilhelmshaven_FSRU
# Lubmin FSRU                                                      https://www.gem.wiki/Lubmin_FSRU
# Revithoussa LNG Terminal                            https://www.gem.wiki/Revithoussa_LNG_Terminal
# Eemshaven FSRU                                                https://www.gem.wiki/Eemshaven_FSRU
# Świnoujście Polskie LNG Terminal  https://www.gem.wiki/%c5%9awinouj%c5%9bcie_Polskie_LNG_Terminal
#
#                                       Country  CapacityInBcm/y     CostEuro  \
# TerminalName
# Krk FSRU                              Croatia             0.30            0
# Hamina LNG Terminal                   Finland             0.14    100000000
# Inkoo FSRU                            Finland             5.00    460000000
# Brunsbüttel FSRU                      Germany             8.00   1000000000
# Wilhelmshaven FSRU                    Germany             7.50    450000000
# Lubmin FSRU                           Germany             4.50  33333333.33
# Revithoussa LNG Terminal               Greece             0.83
# Eemshaven FSRU                    Netherlands             8.00    500000000
# Świnoujście Polskie LNG Terminal       Poland             1.20    427000000
#
#                                   StartYear1  StartMonth1
# TerminalName
# Krk FSRU                                2022            4
# Hamina LNG Terminal                     2022           10
# Inkoo FSRU                              2023            1
# Brunsbüttel FSRU                        2023            2
# Wilhelmshaven FSRU                      2022           12
# Lubmin FSRU                             2023            1
# Revithoussa LNG Terminal                2022           11
# Eemshaven FSRU                          2022           10
# Świnoujście Polskie LNG Terminal        2022            1

# %% [markdown]
# ## Table 2 - starting in 2023 under const

# %%
terms_df_touse_imports.loc[(terms_df_touse_imports.Status.isin(['Construction','Proposed']))&
                           (terms_df_touse_imports.StartYearEarliest.isin([2023,2024,2025,2026,2027,2028,2029,2030]))].groupby(['StartYearEarliest',
                                                                                                           'Status'])[['CapacityInBcm/y']].sum()
# Out:
#                                 CapacityInBcm/y
# StartYearEarliest Status
# 2023              Construction            13.42
#                   Proposed                58.07
# 2024              Construction             6.39
#                   Proposed                30.38
# 2025              Proposed                47.20
# 2026              Construction             1.77
#                   Proposed                41.30
# 2030              Proposed                 7.00

# %% [markdown]
# # existing capacity

# %%
terms_df_touse.loc[(terms_df_touse.Status.isin(['Operating']))&
                   (terms_df_touse['Import/Export']=='Import')]['CapacityInBcm/y'].sum()
# Out:
# 199.98000000000002

# %%
terms_df_touse.loc[(terms_df_touse.Status.isin(['Operating']))&
                   (terms_df_touse['Import/Export']=='Import')
                  ].groupby('StartYear1')[['CapacityInBcm/y']].sum(min_count=0).cumsum()
# Out:
#             CapacityInBcm/y
# StartYear1
# 1969                  17.14
# 1971                  20.54
# 1972                  22.17
# 1980                  33.05
# 1987                  42.03
# 1988                  53.86
# 1989                  65.69
# 2000                  72.63
# 2003                  79.57
# 2004                  87.19
# 2006                  95.89
# 2007                  99.43
# 2009                 108.43
# 2010                 116.68
# 2011                 133.22
# 2014                 141.24
# 2015                 146.27
# 2016                 146.41
# 2017                 160.15
# 2019                 160.69
# 2021                 164.51
# 2022                 182.48
# 2023                 199.98

# %%
terms_df_touse.loc[(terms_df_touse.Status.isin(['Proposed','Construction']))&
                   (terms_df_touse['Import/Export']=='Import')
                  ].groupby('StartYearEarliest')[['CapacityInBcm/y']].sum()#.cumsum()
# Out:
#                    CapacityInBcm/y
# StartYearEarliest
# 2023                         71.49
# 2024                         36.77
# 2025                         47.20
# 2026                         43.07
# 2030                          7.00

# %% [markdown]
# proposed since 2022

# %%
terms_df_touse_imports.loc[terms_df_touse_imports.ProposalYear.isin([2022,2023])]['CapacityInBcm/y'].sum()
# Out:
# 149.38

# %% [markdown]
# began construction since 2022

# %%
terms_df_touse_imports.loc[(terms_df_touse_imports.Status.isin(['Construction','Operating']))&
                           (terms_df_touse_imports.ConstructionYear.isin([2022,2023]))]['CapacityInBcm/y'].sum()
# Out:
# 53.61

# %% [markdown]
# started since 2022

# %%
terms_df_touse_imports.loc[(terms_df_touse_imports.StartYearEarliest.isin([2022,2023]))&
                           (terms_df_touse_imports.Status=='Operating')]['CapacityInBcm/y'].sum()
# Out:
# 35.47

# %% [markdown]
# # hydrogen exploring

# %%
pipes_df_touse = pipes_df_touse.loc[pipes_df_touse.H2Status!='']
pipes_df_touse_h2.H2Status.unique()
# Out:
# array(['Speculative (H2 only)', 'Pre-construction (H2 only)', 'Proposed',
#        'Shelved'], dtype=object)

# %%
pipes_df_touse_h2.loc[pipes_df_touse_h2.Fuel=='Hydrogen'][['ProjectID','Status','H2Status']]
# Out:
#      ProjectID     Status                    H2Status
# 1305     P2477   Proposed                    Proposed
# 2481     P4383   Proposed                    Proposed
# 2482     P4384   Proposed                    Proposed
# 2483     P4385   Proposed                    Proposed
# 2484     P4387   Proposed                    Proposed
# ...        ...        ...                         ...
# 3208     P5116  Operating  Pre-construction (H2 only)
# 3209     P5117   Proposed                    Proposed
# 3210     P5118   Proposed       Speculative (H2 only)
# 3211     P5119   Proposed                    Proposed
# 3212     P5120   Proposed                    Proposed
#
# [65 rows x 3 columns]

# %%
print(pipes_df_touse_h2.loc[pipes_df_touse_h2.H2Status=='Pre-construction (H2 only)'].shape)
print(pipes_df_touse_h2.loc[pipes_df_touse_h2.H2Status=='Speculative (H2 only)'].shape)
print(pipes_df_touse_h2.loc[pipes_df_touse_h2.H2Status=='Proposed'].shape)
# Out:
# (15, 91)
# (63, 91)
# (114, 91)

# %%
117+15+63
# Out:
# 195

# %%
pipes_df_touse_h2.groupby('H2Status')[['LengthMergedKm']].count()#.sum()
# Out:
#                             LengthMergedKm
# H2Status
# Pre-construction (H2 only)              12
# Proposed                               110
# Shelved                                  4
# Speculative (H2 only)                   48

# %% [raw]
# pipes_df_touse_h2.groupby(['H2Status','H2Type'])[['LengthMergedKm']].sum()

# %%
country_ratios_df_touse.loc[(country_ratios_df_touse.H2Status!='')&
                            (country_ratios_df_touse.Country.isin(region_df_touse.Country))].groupby(['H2Status'])[['MergedKmByCountry']].sum()#.sort_values('MergedKmByCountry', ascending=False)
# Out:
#                             MergedKmByCountry
# H2Status
# Pre-construction (H2 only)            1011.61
# Proposed                             16338.36
# Speculative (H2 only)                 4436.00

# %%
country_ratios_df_touse.loc[(country_ratios_df_touse.H2Status!='')&
                            (country_ratios_df_touse.Country.isin(region_df_touse.Country))].groupby(['H2Type'])[['MergedKmByCountry']].sum()#.sort_values('MergedKmByCountry', ascending=False)
# Out:
#                       MergedKmByCountry
# H2Type
# new - blended                   2256.62
# new - unknown                   1998.36
# repurposed - blended           17054.74
# repurposed - unknown             476.25

# %% [raw]
# pipes_df_orig.loc[(pipes_df_orig.H2Status!='')].groupby(['H2Status','H2Type'])[['LengthMergedKm']].sum()#.sort_values('MergedKmByCountry', ascending=False)

# %%
country_ratios_df_touse.loc[(country_ratios_df_touse.H2Status!='')&
                            (country_ratios_df_touse.Country.isin(region_df_touse.Country))].groupby(['H2Status','H2Type'])[['MergedKmByCountry']].sum()#.sort_values('MergedKmByCountry', ascending=False)
# Out:
#                                                  MergedKmByCountry
# H2Status                   H2Type
# Pre-construction (H2 only) repurposed - blended             535.36
#                            repurposed - unknown             476.25
# Proposed                   new - blended                   2097.87
#                            new - unknown                   1409.00
#                            repurposed - blended           12831.49
# Speculative (H2 only)      new - blended                    158.75
#                            new - unknown                    589.36
#                            repurposed - blended            3687.89

# %%
country_ratios_df_touse.loc[(country_ratios_df_touse.H2Status!='')&
                            (country_ratios_df_touse.Country.isin(region_df_touse.Country))].groupby(['H2Status','H2Type'])[['MergedKmByCountry']].count()
# Out:
#                                                  MergedKmByCountry
# H2Status                   H2Type
# Pre-construction (H2 only) repurposed - blended                  4
#                            repurposed - unknown                  3
# Proposed                   new - blended                        25
#                            new - unknown                         4
#                            repurposed - blended                 90
# Speculative (H2 only)      new - blended                         2
#                            new - unknown                         6
#                            repurposed - blended                 30

# %%
country_ratios_df_touse.loc[(country_ratios_df_touse.H2Status!='')&
                            (country_ratios_df_touse.Country.isin(region_df_touse.Country))].groupby(['H2Status','H2Type'])[['MergedKmByCountry']].count()
# Out:
#                                                  MergedKmByCountry
# H2Status                   H2Type
# Pre-construction (H2 only) repurposed - blended                  4
#                            repurposed - unknown                  3
# Proposed                   new - blended                        25
#                            new - unknown                         4
#                            repurposed - blended                 90
# Speculative (H2 only)      new - blended                         2
#                            new - unknown                         6
#                            repurposed - blended                 30

# %%
2256.62+1998.36
# Out:
# 4254.98

# %%
17054.74+476.25
# Out:
# 17530.99

# %%
pipes_df_touse_h2.loc[pipes_df_touse_h2.H2Type.str.contains('blended')|
                      pipes_df_touse_h2.H2Type.str.contains('unknown')].shape
# Out:
# (179, 91)

# %%
pipes_df_touse_h2.loc[pipes_df_touse_h2.H2Type.str.contains('new')]['LengthMergedKm'].sum()
# Out:
# 11602.7

# %%
pipes_df_touse_h2.loc[pipes_df_touse_h2.H2Type.str.contains('repurposed')]['LengthMergedKm'].sum()
# Out:
# 18879.12

# %%
178/195
# Out:
# 0.9128205128205128

# %%
pipes_df_touse_h2.shape
# Out:
# (196, 91)

# %%
pipes_df_touse_h2.loc[pipes_df_touse_h2.H2Status=='Pre-construction (H2 only)']['LengthMergedKm'].sum()
# Out:
# 2055.88

# %% [markdown]
# * how many H2 pipelines are planning to be 100%? blended?
#   * A: really, none; the Malta-Italy Gas Pipeline is actually seeming realistic-ish but has language about "up to 100%" rather than a confirmation

# %% [markdown]
# ## hydrogen table 1

# %%
country_ratios_df_touse.loc[country_ratios_df_touse.H2Status!=''].MergedKmByCountry.sort_values()
# Out:
# 2162       0.00
# 2051       0.00
# 2037       0.00
# 2036       0.00
# 3165       0.00
#          ...
# 1742     427.00
# 1532     500.71
# 1533     749.29
# 829     1110.45
# 1558    2765.00
# Name: MergedKmByCountry, Length: 175, dtype: float64

# %%
# country_ratios_df_touse.loc[country_ratios_df_touse.H2Status!=''].groupby(
#     ['H2Status','Country'])[['MergedKmByCountry']].sum().sort_values('MergedKmByCountry', ascending=False)

country_ratios_df_touse.loc[country_ratios_df_touse.H2Status!=''].groupby(
    ['Country'])[['MergedKmByCountry']].sum().sort_values('MergedKmByCountry', ascending=False)
# Out:
#                         MergedKmByCountry
# Country
# Germany                           3826.63
# Bulgaria                          3312.03
# Italy                             2551.77
# Spain                             2012.82
# Romania                           1913.22
# France                            1430.82
# Croatia                            893.49
# Hungary                            839.10
# Netherlands                        825.25
# Belgium                            734.49
# Austria                            725.88
# Poland                             705.82
# Slovakia                           646.71
# Czech Republic                     364.29
# Portugal                           297.85
# Greece                             196.22
# Lithuania                          165.00
# Bosnia and Herzegovina             158.80
# Slovenia                           118.89
# Estonia                             81.90
# Finland                             73.10
# Malta                               70.29
# United Kingdom                      52.00
# Türkiye                             46.50
# Georgia                             46.50
# Ukraine                             37.64
# Serbia                              17.39
# Denmark                              0.40
# Latvia                               0.00

# %% [markdown]
# # visualize timeline

# %%
terms_df_touse_imports.loc[terms_df_touse_imports.Status.isin(['Operating'])]
# Out:
#     TerminalID ProjectID  ComboID  \
# 96       T0426         0  T042600
# 371      T0430         0  T043000
# 372      T0430         1  T043001
# 412      T0438         0  T043800
# 413      T0440         0  T044000
# 414      T1064         0  T106400
# 417      T0444         0  T044400
# 418      T0446         0  T044600
# 422      T0456         0  T045600
# 424      T0448         0  T044800
# 428      T0452         0  T045200
# 431      T0460         0  T046000
# 434      T0458         0  T045800
# 435      T1077         0  T107700
# 446      T0462         0  T046200
# 447      T0462         1  T046201
# 562      T0476         0  T047600
# 565      T0724         0  T072400
# 569      T0474         0  T047400
# 571      T0466         0  T046600
# 575      T0683         0  T068300
# 642      T0488         0  T048800
# 658      T0490         0  T049000
# 713      T0492         0  T049200
# 717      T0997         0  T099700
# 804      T0498         0  T049800
# 805      T0498         1  T049801
# 808      T0500         0  T050000
# 889      T0532         0  T053200
# 891      T0524         0  T052400
# 893      T0522         0  T052200
# 894      T0534         0  T053400
# 897      T0526         0  T052600
# 899      T0536         0  T053600
# 905      T0539         0  T053900
# 908      T0687         0  T068700
#
#                                                                 Wiki  \
# 96                https://www.gem.wiki/Fluxys_Zeebrugge_LNG_Terminal
# 371                                    https://www.gem.wiki/Krk_FSRU
# 372                                    https://www.gem.wiki/Krk_FSRU
# 412                         https://www.gem.wiki/Hamina_LNG_Terminal
# 413                           https://www.gem.wiki/Pori_LNG_Terminal
# 414                                  https://www.gem.wiki/Inkoo_FSRU
# 417                   https://www.gem.wiki/Tornio_Manga_LNG_Terminal
# 418                        https://www.gem.wiki/Dunkirk_LNG_Terminal
# 422                        https://www.gem.wiki/Montoir_LNG_Terminal
# 424                     https://www.gem.wiki/Fos_Cavaou_LNG_Terminal
# 428                     https://www.gem.wiki/Fos_Tonkin_LNG_Terminal
# 431                            https://www.gem.wiki/Brunsbüttel_FSRU
# 434                          https://www.gem.wiki/Wilhelmshaven_FSRU
# 435                                 https://www.gem.wiki/Lubmin_FSRU
# 446                    https://www.gem.wiki/Revithoussa_LNG_Terminal
# 447                    https://www.gem.wiki/Revithoussa_LNG_Terminal
# 562                     https://www.gem.wiki/Panigaglia_LNG_Terminal
# 565                          https://www.gem.wiki/HIGAS_LNG_Terminal
# 569                        https://www.gem.wiki/Toscana_LNG_Terminal
# 571                https://www.gem.wiki/Adriatic_Rovigo_LNG_Terminal
# 575                        https://www.gem.wiki/Ravenna_LNG_Terminal
# 642                               https://www.gem.wiki/Klaipeda_FSRU
# 658                               https://www.gem.wiki/Delimara_FSRU
# 713                           https://www.gem.wiki/Gate_LNG_Terminal
# 717                              https://www.gem.wiki/Eemshaven_FSRU
# 804  https://www.gem.wiki/%c5%9awinouj%c5%9bcie_Polskie_LNG_Terminal
# 805  https://www.gem.wiki/%c5%9awinouj%c5%9bcie_Polskie_LNG_Terminal
# 808                          https://www.gem.wiki/Sines_LNG_Terminal
# 889                         https://www.gem.wiki/Huelva_LNG_Terminal
# 891                         https://www.gem.wiki/Bilbao_LNG_Terminal
# 893                      https://www.gem.wiki/Barcelona_LNG_Terminal
# 894                       https://www.gem.wiki/Mugardos_LNG_Terminal
# 897              https://www.gem.wiki/Cartagena_LNG_Terminal_(Spain)
# 899                        https://www.gem.wiki/Sagunto_LNG_Terminal
# 905                https://www.gem.wiki/Brunnsviksholme_LNG_Terminal
# 908                        https://www.gem.wiki/Lysekil_LNG_Terminal
#
#                          TerminalName                 UnitName     Status  \
# 96             Zeebrugge LNG Terminal                           Operating
# 371                          Krk FSRU                           Operating
# 372                          Krk FSRU  2022 Capacity Expansion  Operating
# 412               Hamina LNG Terminal                           Operating
# 413                 Pori LNG Terminal                           Operating
# 414                        Inkoo FSRU                           Operating
# 417         Tornio Manga LNG Terminal                           Operating
# 418              Dunkirk LNG Terminal                           Operating
# 422              Montoir LNG Terminal                           Operating
# 424           Fos Cavaou LNG Terminal                           Operating
# 428           Fos Tonkin LNG Terminal                           Operating
# 431                  Brunsbüttel FSRU                           Operating
# 434                Wilhelmshaven FSRU                           Operating
# 435                       Lubmin FSRU                  Phase 1  Operating
# 446          Revithoussa LNG Terminal                           Operating
# 447          Revithoussa LNG Terminal   FSU Capacity Expansion  Operating
# 562           Panigaglia LNG Terminal                           Operating
# 565                HIGAS LNG Terminal                           Operating
# 569                      Toscana FSRU                           Operating
# 571             Adriatic LNG Terminal                           Operating
# 575              Ravenna LNG Terminal                           Operating
# 642                     Klaipeda FSRU                           Operating
# 658                     Delimara FSRU                           Operating
# 713                 Gate LNG Terminal                           Operating
# 717                    Eemshaven FSRU                           Operating
# 804  Świnoujście Polskie LNG Terminal                           Operating
# 805  Świnoujście Polskie LNG Terminal                Expansion  Operating
# 808                Sines LNG Terminal                           Operating
# 889               Huelva LNG Terminal                           Operating
# 891               Bilbao LNG Terminal                           Operating
# 893            Barcelona LNG Terminal                           Operating
# 894             Mugardos LNG Terminal                           Operating
# 897    Cartagena LNG Terminal (Spain)                           Operating
# 899              Sagunto LNG Terminal                           Operating
# 905      Brunnsviksholme LNG Terminal                           Operating
# 908              Lysekil LNG Terminal                           Operating
#
#          Country OtherLanguageName Fuel Import/Export            Type  \
# 96       Belgium                    LNG        Import
# 371      Croatia                    LNG        Import  regasification
# 372      Croatia                    LNG        Import  regasification
# 412      Finland                    LNG        Import
# 413      Finland                    LNG        Import
# 414      Finland                    LNG        Import
# 417      Finland                    LNG        Import
# 418       France                    LNG        Import
# 422       France                    LNG        Import
# 424       France                    LNG        Import
# 428       France                    LNG        Import
# 431      Germany                    LNG        Import
# 434      Germany                    LNG        Import
# 435      Germany                    LNG        Import
# 446       Greece                    LNG        Import
# 447       Greece                    LNG        Import
# 562        Italy                    LNG        Import
# 565        Italy                    LNG        Import
# 569        Italy                    LNG        Import
# 571        Italy                    LNG        Import
# 575        Italy                    LNG        Import
# 642    Lithuania                    LNG        Import
# 658        Malta                    LNG        Import
# 713  Netherlands                    LNG        Import
# 717  Netherlands                    LNG        Import
# 804       Poland                    LNG        Import
# 805       Poland                    LNG        Import
# 808     Portugal                    LNG        Import
# 889        Spain                    LNG        Import
# 891        Spain                    LNG        Import
# 893        Spain                    LNG        Import
# 894        Spain                    LNG        Import
# 897        Spain                    LNG        Import
# 899        Spain                    LNG        Import
# 905       Sweden                    LNG        Import
# 908       Sweden                    LNG        Import
#
#     Researcher LastUpdated  \
# 96
# 371         GA  2022/04/27
# 372         BL  2023/03/08
# 412         RR  2022/12/13
# 413
# 414         SZ  2022/06/30
# 417
# 418         SZ  2022/07/05
# 422
# 424         RR  2022/12/23
# 428         SZ  2022/07/05
# 431         BL  2023/03/05
# 434         RR  2022/12/19
# 435         GA  2022/09/26
# 446         SZ  2022/07/05
# 447         RR  2023/01/04
# 562         SZ  2022/07/05
# 565         SZ  2022/07/05
# 569         SZ  2022/07/05
# 571         GA  2022/05/03
# 575         SZ  2022/07/05
# 642
# 658
# 713         SZ  2022/07/05
# 717         GA  2022/11/29
# 804         SZ  2022/07/05
# 805         GC  2022/06/23
# 808         SZ  2022/07/05
# 889         SZ  2022/07/05
# 891         SZ  2022/07/05
# 893         SZ  2022/07/05
# 894         SZ  2022/07/05
# 897         SZ  2022/07/05
# 899         SZ  2022/07/05
# 905         SZ  2022/07/05
# 908         SZ  2022/07/05
#
#                                                      OtherEnglishNames  \
# 96
# 371               Hrvatska LNG Terminal, LNG Croatia, Krk LNG Terminal
# 372               Hrvatska LNG Terminal, LNG Croatia, Krk LNG Terminal
# 412
# 413
# 414                                                      Exemplar FSRU
# 417
# 418                                             Dunkerque LNG Terminal
# 422                                   Montoir-de-Bretagne LNG Terminal
# 424
# 428
# 431  Hamburg LNG Terminal, German LNG Terminal, Elbehafen LNG Terminal
# 434
# 435             German Baltic Sea, Deutsche Ostsee LNG Import Terminal
# 446
# 447
# 562
# 565                                          Santa Giusta LNG Terminal
# 569                                               Livorno LNG Terminal
# 571    Terminale GNL Adriatico Srl, Porto Levante LNG Terminal, Rovigo
# 575
# 642                                                       Independence
# 658                                             Armada LNG Mediterrana
# 713                                                      Gate terminal
# 717                           EemsEnergyTerminal, Eems Energy Terminal
# 804                                           Świnoujście LNG Terminal
# 805                                           Świnoujście LNG Terminal
# 808
# 889
# 891                                      Bahia de Bizkaia Gas Terminal
# 893
# 894                                                    Reganosa Ferrol
# 897
# 899                                                             Saggas
# 905                                                          Nynäshamn
# 908
#
#     QCCOwnerCURRENT QCCOwnerUPDATED  \
# 96
# 371
# 372
# 412
# 413
# 414
# 417
# 418
# 422
# 424
# 428
# 431
# 434
# 435
# 446
# 447
# 562
# 565
# 569
# 571
# 575
# 642
# 658
# 713
# 717
# 804
# 805
# 808
# 889
# 891
# 893
# 894
# 897
# 899
# 905
# 908
#
#                                                                                                                                                    Owner  \
# 96                                                                                                                                      Fluxys [100.00%]
# 371                                                                                                                HEP Grupa [85.00%]; Plinacro [15.00%]
# 372                                                                                                                HEP Grupa [85.00%]; Plinacro [15.00%]
# 412                                                                                 Alexela [unknown %]; Hamina Energy [unknown %]; Wärtsilä [unknown %]
# 413                                                                                                                                      Gasum [100.00%]
# 414                                                                                                                         Gasgrid Finland Oy [100.00%]
# 417                                                                          Outokumpu Group [45.00%]; Gasum [25.00%]; SSAB [25.00%]; EPV Energy [5.00%]
# 418  Fluxys [30.38%]; Axa [15.19%]; Credit Agricole Group [15.19%]; Hanwha Investment and Securities [13.08%]; IBK Securities [13.08%]; Samsung [13.08%]
# 422                                                                                                                                      Engie [100.00%]
# 424                                                                                                                                      Engie [100.00%]
# 428                                                                                                                                      Engie [100.00%]
# 431                                                                                                                        German LNG Terminal [100.00%]
# 434                                                                                                                                     Uniper [100.00%]
# 435                                                                                                                           Deutsche Regas [unknown %]
# 446                                                                                                                                      DESFA [100.00%]
# 447                                                                                                                                      DESFA [100.00%]
# 562                                                                                                                                       Snam [100.00%]
# 565                                                               CPL Concordia [unknown %]; Gas and Heat [unknown %]; Stolt-Nielsen Limited [unknown %]
# 569                                                                            Snam [49.07%]; Mitsubishi UFJ Financial Group [48.24%]; Golar LNG [2.69%]
# 571                                                                         ExxonMobil [70.70%]; QatarEnergy [22.00%]; Cassa Depositi e Prestiti [7.30%]
# 575                                                                                      Edison S.p.A. [unknown %]; Petrolifera Italo Rumena [unknown %]
# 642                                                                                                                            Klaipėdos Nafta [100.00%]
# 658                                                                                                                                Bumi Armada [100.00%]
# 713                                                                                                                     Gasunie [50.00%]; Vopak [50.00%]
# 717                                                                                                                      EemsEnergyTerminal BV [100.00%]
# 804                                                                                                                                      PGNiG [100.00%]
# 805                                                                                                                                      PGNiG [100.00%]
# 808                                                                                                                              REN Atlantico [100.00%]
# 889                                                                                                                                     Enagás [100.00%]
# 891                                                                                                  Basque Energy Board (EVE) [50.00%]; Enagás [50.00%]
# 893                                                                                                                                     Enagás [100.00%]
# 894                                             Tojeiro Group [51.00%]; Government of Galician [24.00%]; Sojitz Corporation [15.00%]; Sonatrach [10.00%]
# 897                                                                                                                                     Enagás [100.00%]
# 899                                                                                        Enagás [72.50%]; Osaka Gas [20.00%]; Oman Oil Company [7.50%]
# 905                                                                                                                                    AGA Gas [100.00%]
# 908                                                                                                                                      Gasum [100.00%]
#
#                                                                                                                                                   Parent  \
# 96                                                                                                                                      Fluxys [100.00%]
# 371                                                                                                                HEP Grupa [85.00%]; Plinacro [15.00%]
# 372                                                                                                                HEP Grupa [85.00%]; Plinacro [15.00%]
# 412                                                                                 Alexela [unknown %]; Hamina Energy [unknown %]; Wärtsilä [unknown %]
# 413                                                                                                                                      Gasum [100.00%]
# 414                                                                                                                         Gasgrid Finland Oy [100.00%]
# 417                                                                          Outokumpu Group [45.00%]; Gasum [25.00%]; SSAB [25.00%]; EPV Energy [5.00%]
# 418  Fluxys [30.38%]; Axa [15.19%]; Credit Agricole Group [15.19%]; Hanwha Investment and Securities [13.08%]; IBK Securities [13.08%]; Samsung [13.08%]
# 422                                                                                                                                      Engie [100.00%]
# 424                                                                                                                                      Engie [100.00%]
# 428                                                                                                                                      Engie [100.00%]
# 431                                                                              Kreditanstalt für Wiederaufbau [50.00%]; Gasunie [40.00%]; RWE [10.00%]
# 434                                                                                                                                     Uniper [100.00%]
# 435                                                                                                                           Deutsche Regas [unknown %]
# 446                                                                                                                                      DESFA [100.00%]
# 447                                                                                                                                      DESFA [100.00%]
# 562                                                                                                                                       Snam [100.00%]
# 565                                                               CPL Concordia [unknown %]; Gas and Heat [unknown %]; Stolt-Nielsen Limited [unknown %]
# 569                                                                            Snam [49.07%]; Mitsubishi UFJ Financial Group [48.24%]; Golar LNG [2.69%]
# 571                                                                         ExxonMobil [70.70%]; QatarEnergy [22.00%]; Cassa Depositi e Prestiti [7.30%]
# 575                                                          Electricité de France  [unknown %]; Other [unknown %]; Petrolifera Italo Rumena [unknown %]
# 642                                 Valstybė, atstovaujama LR energetikos ministerijos  [72.47%]; Other [17.10%]; UAB koncernas "Achemos grupė" [10.43%]
# 658                                                                                                                                Bumi Armada [100.00%]
# 713                                                                                                                     Gasunie [50.00%]; Vopak [50.00%]
# 717                                                                                                                                    Gasunie [100.00%]
# 804                                                                                                                                      PGNiG [100.00%]
# 805                                                                                                                                      PGNiG [100.00%]
# 808                                                                                                                              REN Atlantico [100.00%]
# 889                                                                                                                                     Enagás [100.00%]
# 891                                                                                                  Basque Energy Board (EVE) [50.00%]; Enagás [50.00%]
# 893                                                                                                                                     Enagás [100.00%]
# 894                                             Tojeiro Group [51.00%]; Government of Galician [24.00%]; Sojitz Corporation [15.00%]; Sonatrach [10.00%]
# 897                                                                                                                                     Enagás [100.00%]
# 899                                                                                        Enagás [72.50%]; Osaka Gas [20.00%]; Oman Oil Company [7.50%]
# 905                                                                                                                                    AGA Gas [100.00%]
# 908                                                                                                                                      Gasum [100.00%]
#
#     ProposalYear ProposalMonth ConstructionYear ConstructionMonth StartYear1  \
# 96          1976                           1982                         1987
# 371         2015                                                        2021
# 372         2022             3             2022                 3       2022
# 412         2014            12             2017                 5       2022
# 413         2014                           2014                         2016
# 414         2022             4             2022                 8       2023
# 417         2013                           2015                         2019
# 418         2009                           2011                 6       2017
# 422                                                                     1980
# 424         2005                           2005                 2       2010
# 428                                                                     1972
# 431         2022             2             2022                 9       2023
# 434         2022             2             2022                 5       2022
# 435         2022             4             2022                 9       2023
# 446                                                                     2000
# 447         2022             4             2022                 5       2022
# 562                                                                     1971
# 565         2015                           2018                         2021
# 569         2002                           2009                         2014
# 571                                                                     2009
# 575         2017                           2018                         2021
# 642         2011                           2012                         2014
# 658         2013                           2014                         2017
# 713         2005                           2007                         2011
# 717         2022             3             2022                 5       2022
# 804         2006                           2011                         2015
# 805         2017             4             2021                 2       2022
# 808                                                                     2004
# 889                                                                     1988
# 891                                                                     2003
# 893                                                                     1969
# 894                                                                     2007
# 897                                                                     1989
# 899                                                                     2006
# 905                                        2009                         2011
# 908         2012                           2012                         2014
#
#     StartMonth1 StartYear2 StartYear3       DelayedStartYear Delayed  \
# 96                    2018
# 371           1
# 372           4
# 412          10                                                  Yes
# 413
# 414           1
# 417                                                              Yes
# 418           1
# 422
# 424
# 428
# 431           2                        2023, originally 2022     Yes
# 434          12
# 435           1
# 446
# 447          11                                                  Yes
# 562
# 565
# 569
# 571
# 575
# 642
# 658
# 713
# 717          10
# 804
# 805           1
# 808
# 889
# 891
# 893
# 894
# 897
# 899
# 905
# 908
#
#      DelayType StartYearEarliest ShelvedYear CancelledYear StopYear  \
# 96                          1987
# 371                         2021
# 372                         2022
# 412  Confirmed              2022
# 413                         2016
# 414                         2023
# 417  Confirmed              2019
# 418                         2017
# 422                         1980
# 424                         2010
# 428                         1972
# 431  Confirmed              2023
# 434                         2022                      2021
# 435                         2023
# 446                         2000
# 447   Presumed              2022
# 562                         1971
# 565                         2021
# 569                         2014
# 571                         2009
# 575                         2021
# 642                         2014
# 658                         2017
# 713                         2011
# 717                         2022
# 804                         2015
# 805                         2022
# 808                         2004
# 889                         1988
# 891                         2003
# 893                         1969
# 894                         2007
# 897                         1989
# 899                         2006
# 905                         2011
# 908                         2014
#
#     ShelvedCancelledStatusType Capacity CapacityUnits CapacityInMtpa  \
# 96                                  6.6          mtpa            6.6
# 371                                 2.6         bcm/y           1.91
# 372                                 0.3         bcm/y           0.22
# 412                                 0.1          mtpa            0.1
# 413                                 0.1          mtpa            0.1
# 414                                 5.0         bcm/y           3.68
# 417                                 0.4          mtpa            0.4
# 418                                 9.6          mtpa            9.6
# 422                                 8.0          mtpa            8.0
# 424                                8.25         bcm/y           6.07
# 428                                 1.2          mtpa            1.2
# 431                                 8.0         bcm/y           5.88
# 434                                 7.5         bcm/y           5.51
# 435                                 4.5         bcm/y           3.31
# 446                                 5.1          mtpa            5.1
# 447                               0.828         bcm/y           0.61
# 562                                 2.5          mtpa            2.5
# 565                                 0.2          mtpa            0.2
# 569                                 2.8          mtpa            2.8
# 571                                 9.0         bcm/y           6.62
# 575                                 0.7          mtpa            0.7
# 642                                 2.9          mtpa            2.9
# 658                                 0.5          mtpa            0.5
# 713                                16.0         bcm/y          11.76
# 717                                 8.0         bcm/y           5.88
# 804                                 3.7          mtpa            3.7
# 805                                 1.2         bcm/y           0.88
# 808                                 5.6          mtpa            5.6
# 889                                 8.7          mtpa            8.7
# 891                                 5.1          mtpa            5.1
# 893                                12.6          mtpa           12.6
# 894                                 2.6          mtpa            2.6
# 897                                 8.7          mtpa            8.7
# 899                                 6.4          mtpa            6.4
# 905                                 0.4          mtpa            0.4
# 908                                 0.2          mtpa            0.2
#
#     CapacityInBcm/y  Region  \
# 96             8.98  Europe
# 371             2.6  Europe
# 372             0.3  Europe
# 412            0.14  Europe
# 413            0.14  Europe
# 414             5.0  Europe
# 417            0.54  Europe
# 418           13.06  Europe
# 422           10.88  Europe
# 424            8.25  Europe
# 428            1.63  Europe
# 431             8.0  Europe
# 434             7.5  Europe
# 435             4.5  Europe
# 446            6.94  Europe
# 447            0.83  Europe
# 562             3.4  Europe
# 565            0.27  Europe
# 569            3.81  Europe
# 571             9.0  Europe
# 575            0.95  Europe
# 642            3.94  Europe
# 658            0.68  Europe
# 713            16.0  Europe
# 717             8.0  Europe
# 804            5.03  Europe
# 805             1.2  Europe
# 808            7.62  Europe
# 889           11.83  Europe
# 891            6.94  Europe
# 893           17.14  Europe
# 894            3.54  Europe
# 897           11.83  Europe
# 899             8.7  Europe
# 905            0.54  Europe
# 908            0.27  Europe
#
#                                                       Location  \
# 96                                                   Zeebrugge
# 371                                        Omišalj, Krk Island
# 372                                        Omišalj, Krk Island
# 412                                             Port of Hamina
# 413                                         Port of Tahkoluoto
# 414                                                 Inkoo port
# 417                            Tornio harbour, Port of Röyttä,
# 418                                                    Dunkirk
# 422                                        Montoir-de-Bretagne
# 424                                                Fos-sur-Mer
# 428                                                Fos-sur-Mer
# 431                                                Brunsbüttel
# 434                                              Wilhelmshaven
# 435                                             Port of Lubmin
# 446                                         Revithoussa Island
# 447                                         Revithoussa Island
# 562                                               Porto Venere
# 565                                                   Oristano
# 569                                                   offshore
# 571                                                   offshore
# 575                                            Port of Ravenna
# 642                                              Klaipeda Port
# 658                                                 Marsaxlokk
# 713                              Maasvlakte, Port of Rotterdam
# 717                                                  Eemshaven
# 804                                                Świnoujście
# 805                                                Świnoujście
# 808                                                      Sines
# 889                                                     Huelva
# 891                                             Port of Bilbao
# 893                                                  Barcelona
# 894                                                   Mugardos
# 897                                           Escombreras Dock
# 899                                               Sagunto Port
# 905  Brunnsviksholme, Nynäshamn Municipality, Stockholm County
# 908
#
#     Prefecture/District              State/Province   Latitude  Longitude  \
# 96               Bruges               West Flanders     51.353    3.22241
# 371                           Primorje-Gorski Kotar  45.188543  14.545081
# 372                           Primorje-Gorski Kotar  45.188543  14.545081
# 412              Hamina                 Kymenlaakso  60.518314   27.16082
# 413                Pori                   Satakunta   61.63817   21.39881
# 414                                Southern Finland  60.013697   23.91506
# 417                                                  65.847366  24.152152
# 418                Nord             Hauts-de-France   51.03361    2.19653
# 422    Loire-Atlantique            Pays de la Loire   47.30296   -2.14278
# 424    Bouches-du-Rhône  Provence-Alpes-Côte d'Azur   43.41963    4.90102
# 428    Bouches-du-Rhône  Provence-Alpes-Côte d'Azur     43.454    4.85167
# 431                                         Hamburg  53.914001   8.976095
# 434                                    Lower Saxony  53.516667   8.133333
# 435                                                  54.153332  13.645319
# 446          Megara Bay                      Attica      37.96    23.4023
# 447          Megara Bay                      Attica      37.96    23.4023
# 562           La Spezia                     Liguria   44.07428    9.83087
# 565                                        Sardinia  39.863873   8.554238
# 569             Livorno                     Toscana  43.644444   9.988889
# 571              Rovigo                      Veneto  45.091667  12.586111
# 575                                                  44.471734  12.248134
# 642            Klaipeda                               55.66451   21.13762
# 658                            South Eastern Region    35.8277    14.5542
# 713           Rotterdam               South Holland  51.971111   4.068889
# 717                                                  53.435649   6.833098
# 804         Świnoujście                 Województwo  53.909167  14.294722
# 805         Świnoujście                 Województwo  53.909167  14.294722
# 808             Setúbal                    Alentejo    37.9419    -8.8435
# 889                                       Andalusia   37.17355     -6.911
# 891            Zierbena                      Biscay    43.3612   -3.09473
# 893                                       Catalonia    41.3394     2.1583
# 894           La Coruna                     Galicia    43.4613    -8.2395
# 897           Cartagena          Province of Murcia   37.57457    -0.9595
# 899                                        Valencia    39.6329    -0.2152
# 905                                                  58.922139  17.976153
# 908                                                  58.274285  11.452119
#
#         Accuracy Source PowerPlantsSupplied        Cost CostUnits CostYear  \
# 96         exact
# 371  approximate                              233600000       EUR     2020
# 372  approximate                                      0       EUR     2022
# 412  approximate                              100000000       EUR     2018
# 413        exact                               88000000       USD     2016
# 414  approximate                              460000000       EUR     2022
# 417        exact
# 418        exact
# 422        exact
# 424        exact
# 428        exact
# 431  approximate                             1000000000       EUR     2022
# 434  approximate                              450000000       EUR     2022
# 435  approximate                               33333333       EUR     2022
# 446        exact
# 447        exact
# 562        exact
# 565  approximate                               38200000       EUR     2020
# 569  approximate                              550000000       EUR     2008
# 571        exact
# 575  approximate                              100000000       EUR     2020
# 642        exact                              350000000       LTL     2014
# 658        exact
# 713        exact
# 717  approximate                              500000000       EUR     2022
# 804        exact
# 805        exact                              427000000       EUR     2021
# 808        exact
# 889        exact
# 891        exact
# 893        exact
# 894        exact
# 897        exact
# 899        exact
# 905        exact                              275000000       SWE     2011
# 908  approximate
#
#          CostUSD     CostEuro CostUSDPerMtpa CostUSDPerBcm/y CostEuroPerMtpa  \
# 96           NaN          NaN            NaN             NaN             NaN
# 371    254624000    233600000      133187926      97932307.7     122190757.8
# 372            0            0              0               0               0
# 412    109000000    100000000     1090000000     801470663.1      1000000000
# 413     88000000  80733944.95      880000000     647058883.9     807339449.5
# 414    501400000    460000000    136380787.3       100280000     125119988.3
# 417          NaN          NaN            NaN             NaN             NaN
# 418          NaN          NaN            NaN             NaN             NaN
# 422          NaN          NaN            NaN             NaN             NaN
# 424          NaN          NaN            NaN             NaN             NaN
# 428          NaN          NaN            NaN             NaN             NaN
# 431   1090000000   1000000000    185299982.7       136250000     169999984.1
# 434    490500000    450000000     88943991.7        65400000     81599992.38
# 435  36333333.33  33333333.33    10980739.72     8074074.074     10074073.13
# 446          NaN          NaN            NaN             NaN             NaN
# ...
# 417
# 418
# 422
# 424
# 428
# 431  for the future - terminal being designed "in such a way that green hydrogen or hydrogen derivatives (such as ammonia) can be imported at a later date"
# 434                                                                 GA: adjoining but seperate green gases (ammonia) terminal to come in Phase 2, post 2025
# 435
# 446
# 447
# 562
# 565
# 569
# 571
# 575
# 642
# 658
# 713
# 717                                                                                                                             plan for the future (maybe)
# 804
# 805
# 808
# 889
# 891
# 893
# 894
# 897
# 899
# 905
# 908
#
#     CCS CCSNotes EuroCrisisTracker  \
# 96
# 371
# 372                            yes
# 412
# 413
# 414                            yes
# 417
# 418
# 422
# 424
# 428
# 431                            yes
# 434                            yes
# 435                            yes
# 446
# 447                            yes
# 562
# 565
# 569
# 571
# 575
# 642
# 658
# 713
# 717                            yes
# 804
# 805
# 808
# 889
# 891
# 893
# 894
# 897
# 899
# 905
# 908
#
#                                                                                                                                                                                 ResearcherNotes  \
# 96
# 371
# 372
# 412
# 413                                                                                                                                               Storage terminal - not sure it should be here
# 414                                                                                                                                                     to be jointly leased with Paldiski FSRU
# 417                                                                                            Tornio Manga LNG Terminal will primarily provide natural gas to the Outokumpu Tornio steel mill.
# 418
# 422                                                                               Expanded in 2012 and 2014? http://www.giignl.org/system/files/q-flexq-max_acceptability_database_-_march_.pdf
# 424
# 428
# 431
# 434
# 435  On costs: the investment associated with Phase 1 is estimated to be its share of total capacity. However, the value ($100 M euros) is "funds already available." It may not be total costs
# 446                                                                                         Expanded in 2016: http://www.kslaw.com/imageserver/KSPublic/practice_areas/energy/LNG-In-Europe.pdf
# 447
# 562                                                                                       Proposed expansion: http://www.kslaw.com/imageserver/KSPublic/practice_areas/energy/LNG-In-Europe.pdf
# 565
# 569
# 571
# 575
# 642
# 658
# 713
# 717
# 804
# 805
# 808
# 889
# 891                                                   This says a 1.37 mtpa expansion was completed in 2015: http://www.giignl.org/system/files/q-flexq-max_acceptability_database_-_march_.pdf
# 893
# 894                                                                                      1.8 mtpa expansion? http://www.giignl.org/system/files/q-flexq-max_acceptability_database_-_march_.pdf
# 897
# 899
# 905
# 908
#
#     Construction_Sanctioned_July_2022 ImpactedByRussiaUkraineInvasion
# 96
# 371
# 372
# 412
# 413
# 414
# 417
# 418
# 422
# 424
# 428
# 431
# 434
# 435
# 446
# 447
# 562
# 565
# 569
# 571
# 575
# 642
# 658
# 713
# 717
# 804
# 805
# 808
# 889
# 891
# 893
# 894
# 897
# 899
# 905
# 908

# %% [markdown]
# # IEEFA report

# %%
terms_df_orig.loc[(terms_df_orig.Region=='Europe')&
                  (terms_df_orig['Import/Export']=='Import')&
                  (terms_df_orig.Status=='Operating')]['CapacityInBcm/y'].sum()
# Out:
# 275.20000000000005

# %%
terms_df_orig.loc[(terms_df_orig.Region=='Europe')&
                  (terms_df_orig['Import/Export']=='Import')&
                  (terms_df_orig.Status.isin(['Proposed','Construction']))]['CapacityInBcm/y'].sum()
# Out:
# 246.52999999999997

# %%
terms_df_orig.loc[(terms_df_orig.EuroCrisisTracker=='yes')&
                  (terms_df_orig['Import/Export']=='Import')&
                  (terms_df_orig.Status.isin(['Proposed','Construction']))]['CapacityInBcm/y'].sum()
# Out:
# 154.84

# %%
275.2+246.5
# Out:
# 521.7

# %%
275.2+154.84
# Out:
# 430.03999999999996

# %% [markdown]
# # CAN webinar matches?

# %%
terms_df_orig.loc[(terms_df_orig.EuroCrisisTracker=='yes')&
                  (terms_df_orig['Import/Export']=='Import')&
                  (terms_df_orig.Status.isin(['Proposed','Construction']))&
                  (terms_df_orig.StartYearEarliest.isin([2022,2023,2024]))]['CapacityInBcm/y'].sum()
# Out:
# 64.04

# %%
terms_df_orig.loc[#(terms_df_orig.EuroCrisisTracker=='yes')&
                  (terms_df_orig.Country.isin(region_df_eu.Country))&
                  (terms_df_orig['Import/Export']=='Import')&
                  (terms_df_orig.Status.isin(['Proposed','Construction']))&
                  (terms_df_orig.StartYearEarliest.isin([2022,2023,2024]))]['CapacityInBcm/y'].sum()
# Out:
# 108.25999999999999

# %%
terms_df_orig.loc[#(terms_df_orig.EuroCrisisTracker=='yes')&
                  (terms_df_orig.Country.isin(region_df_eu.Country))&
                  (terms_df_orig['Import/Export']=='Import')&
                  (terms_df_orig.Status.isin(['Proposed','Construction']))&
                  (~terms_df_orig.StartYearEarliest.isnull())]['CapacityInBcm/y'].sum()
# Out:
# 205.53

# %%
terms_df_orig.loc[#(terms_df_orig.EuroCrisisTracker=='yes')&
                  (terms_df_orig.Country.isin(region_df_eu.Country))&
                  (terms_df_orig['Import/Export']=='Import')&
                  (terms_df_orig.Status.isin(['Proposed','Construction']))]['CapacityInBcm/y'].sum()
# Out:
# 227.2

# %%
terms_df_orig.loc[#(terms_df_orig.EuroCrisisTracker=='yes')&
                  (terms_df_orig.Country.isin(region_df_eu.Country))&
                  (terms_df_orig['Import/Export']=='Import')&
                  (terms_df_orig.Status.isin(['Operating']))]['CapacityInBcm/y'].sum()
# Out:
# 199.98000000000002
